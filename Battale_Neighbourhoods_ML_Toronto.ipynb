# %% [markdown]
# <a href="https://colab.research.google.com/github/angui100/Coursera__Capstone/blob/master/Battale_Neighbourhoods_ML_Toronto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week-1 and Week-2 Tasks
#
# ## 1. Introduction of the Business Problem
#
# The goal of this study is to help a small investor team planning to open a **Youth and Child Learning Center**  in City of Toronto, Ontario, Canada. Being that Toronto is the most populated city in Canada, and continually ranks as an important global city based on a high quality of education, the choice to expand business into the neighbor was an easy selection for the investor team. However, with limited information of the Toronto market, this team needs us to assist in the selection of which area of Toronto will facilitate their **Learning Centers**.
#
# They are interested in openning a learning center in an area that meet the following criteria:
#
# - A neighborhood with an average to above average population of children or youth
# - Average to above average median after tax household incomes
# - A neighborhood with an average to above population of people who has college degree
#
#
# With these criteria given by the investor team, based on previous success in other markets, the objective is to locate and recommend to the investors, the target audience, which neighborhood(s) of Toronto will be the best choice to operate their **Youth and Child Learning Center**. The information gained will assist in choosing the right location by providing data about the population of each neighborhood, in addition to other established venues present in these areas.

# %% [markdown]
# ## 2. Data — The essential information needed for achieve our goal
#
# - City of Toronto Neighborhood Profiles for providing an overview of the neighborhoods in Toronto(
#   <a ref="https://www.toronto.ca/city-government/data-research-maps/neighbourhoods-communities/neighbourhood-profiles/">https://www.toronto.ca/city-government/data-research-maps/neighbourhoods-communities/neighbourhood-profiles/</a> ).
#
# - City of Toronto Open Data Catalogue : The Census of Population is held across Canada every five years (the last being in 2016), and collects data about age and sex, families and households, language, immigration and internal migration, ethnocultural diversity, Aboriginal peoples, housing, education, income, and labor. City of Toronto Neighborhood Profiles use this Census data to provide a portrait of the demographic, social and economic characteristics of the people and households in each City of Toronto neighborhood. The profiles present selected highlights from the data, but these accompanying data files provide the full data set assembled for each neighborhood(
# <a ref="https://www.toronto.ca/city-government/data-research-maps/open-data/open-data-catalogue/#8c732154-5012-9afe-d0cd-ba3ffc813d5a">https://www.toronto.ca/city-government/data-research-maps/open-data/open-data-catalogue/#8c732154-5012-9afe-d0cd-ba3ffc813d5a</a>
# ).
#
# - Here is the Data File in CSV format (<a ref="https://www.toronto.ca/ext/open_data/catalog/data_set_files/2016_neighbourhood_profiles.csv">https://www.toronto.ca/ext/open_data/catalog/data_set_files/2016_neighbourhood_profiles.csv</a>). Each data point in this file is presented for the City’s 140 neighborhoods, as well as for the City of Toronto as a whole. The data is sourced from several Census tables released by Statistics Canada. The general Census Profile is the main source table for this data, but other Census tables have also been used to provide additional information.
#
# - Here is the Wikipedia for Toronto Neighborhood Borough Designation (<a ref="https://en.wikipedia.org/wiki/List_of_city-designated_neighbourhoods_in_Toronto">https://en.wikipedia.org/wiki/List_of_city-designated_neighbourhoods_in_Toronto</a>). Each of the 140 social planning neighborhoods of Toronto reside within a defined borough. While the City of Toronto is a singular municipality, the 140 neighborhoods are still grouped into six distinct boroughs.
#
# - Foursquare API (<a ref="https://developer.foursquare.com/">https://developer.foursquare.com/</a>) to collect information on other venues/competitors in the neighborhoods of Toronto.

# %% [markdown]
# # Discussion - Week 1
# ## 3. Methodology — In order to establish the targeted neighborhood(s), we will explore the demographics of the neighborhoods in the city of Toronto by segmenting the data and conducting descriptive analysis using Panda.
# Data Group 1
# Stage A — Census Data
# 1. Data was pulled into from the City of Toronto Neighborhoods Profile Census CSV File to create a dataframe.
# 2. This dataframe contains all the census data (2016) of the neighborhoods of Toronto that will be filtered.
# 3. Data is filtered into columns based on neighborhood population, Children and Youth age groups, education level, and after-tax income.
#
# Stage B — Neighbourhood Geogrophic information data
# 1. Geographic data file has Neighbourhood code, Neightbourhood name, Geo Latitude, Logitude
# 3. Merge this Neighbourhood GEO dataframe with Census Data dataframe.
#
# Data Group 2
# Stage A — Establish Medians and scoring system
# 1. Calculate medians of the demographic columns across the 140 neighborhoods.
# Median Children Population: 2844
# Median Youth Population: 2431
# Median College Education: 3819
# Median After Tax Household Income: $35127.6
#
#
# 2. From the criteria delivered by the investor team, each category was given a standardized score based the category being divided by its median score and then multiplied by a factor of given importance. The columns are the summed to create a complex score for each neighborhood. The dataframe is then merged to create a dataframe with all necessary data.
#
#
# 3. From here, utilizing a choropleth folium map, a clearer picture of the neighborhoods of Toronto becomes apparent.
#
# Data Group 3
# Stage A — Toronto geographical data is utilized as the input into the Foursquare API, that returned venues from all of Toronto
# 1. Using the geographical coordinates of each neighborhood in Toronto, calls are made to the Foursquare API to return the top 100 venues in a radius of 1000 meters.
# 2. The data is then visualized via a folium map.
#
# 3. Foursquare is called on again to narrow the list to the neighborhoods within the top fifteen (15) total score (with the same parameters as the previous call), and this data is mapped as well.
#
# Data Group 4
# Stage A — Analyze the Top 15 neighborhoods of Toronto
# 1. Utilize one hot encoding to transform our list of established venues in the top 15 neighborhoods to return all Venue category information
#
# 2. Group by neighborhoods. Filter out venues related to retail and personal care categories to focus on learning activity centered venues (i.e. school, music center, bookstore, etc…). Create a small dataframe to display totals for each neighborhood.

# %% [markdown]
# ### Import all required Python packages for data processing work

# %%
#import all required packages
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %% [markdown]
# #### A simple numeric data format setting

# %%
import locale
from locale import atof

locale.setlocale(locale.LC_NUMERIC, '')
#df.applymap(atof)
# Out:
# 'en_US.UTF-8'

# %% [markdown]
# # City of Toronto 2016 Census data analsys

# %% [markdown]
# ### 1. Load the Census information into Pandas DataFrame

# %%
#Read Census Data File
df_census = pd.read_csv(r'2016_neighbourhood_profiles.csv', encoding = "ISO-8859-1", thousands=',')

df_census.shape
# Out:
# (2383, 145)

# %%
df_census.head()
# Out:
#                     Category                      Topic  \
# 0  Neighbourhood Information  Neighbourhood Information
# 1  Neighbourhood Information  Neighbourhood Information
# 2                 Population   Population and dwellings
# 3                 Population   Population and dwellings
# 4                 Population   Population and dwellings
#
#                       Data Source               Characteristic  \
# 0                 City of Toronto         Neighbourhood Number
# 1                 City of Toronto         TSNS2020 Designation
# 2  Census Profile 98-316-X2016001             Population, 2016
# 3  Census Profile 98-316-X2016001             Population, 2011
# 4  Census Profile 98-316-X2016001  Population Change 2011-2016
#
#   City of Toronto Agincourt North Agincourt South-Malvern West  \
# 0             NaN             129                          128
# 1             NaN  No Designation               No Designation
# 2       2,731,571          29,113                       23,757
# 3       2,615,060          30,279                       21,988
# 4           4.50%          -3.90%                        8.00%
#
#         Alderwood           Annex Banbury-Don Mills  Bathurst Manor  \
# 0              20              95                42              34
# 1  No Designation  No Designation    No Designation  No Designation
# 2          12,054          30,526            27,695          15,873
# 3          11,904          29,177            26,918          15,434
# 4           1.30%           4.60%             2.90%           2.80%
#
#   Bay Street Corridor Bayview Village Bayview Woods-Steeles  \
# 0                  76              52                    49
# 1      No Designation  No Designation        No Designation
# 2              25,797          21,396                13,154
# 3              19,348          17,671                13,530
# 4              33.30%          21.10%                -2.80%
#
#   Bedford Park-Nortown Beechborough-Greenbrook         Bendale  \
# 0                   39                     112             127
# 1       No Designation                     NIA  No Designation
# 2               23,236                   6,577          29,960
# 3               23,185                   6,488          27,876
# 4                0.20%                   1.40%           7.50%
#
#   Birchcliffe-Cliffside Black Creek     Blake-Jones Briar Hill-Belgravia  \
# 0                   122          24              69                  108
# 1        No Designation         NIA  No Designation       No Designation
# 2                22,291      21,737           7,727               14,257
# 3                21,856      22,057           7,763               14,302
# 4                 2.00%      -1.50%          -0.50%               -0.30%
#
#   Bridle Path-Sunnybrook-York Mills Broadview North Brookhaven-Amesbury  \
# 0                                41              57                  30
# 1                    No Designation  No Designation      No Designation
# 2                             9,266          11,499              17,757
# 3                             8,713          11,563              17,787
# 4                             6.30%          -0.60%              -0.20%
#
#   Cabbagetown-South St. James Town Caledonia-Fairbank       Casa Loma  \
# 0                               71                109              96
# 1                   No Designation     No Designation  No Designation
# 2                           11,669              9,955          10,968
# 3                           12,053              9,851          10,487
# 4                           -3.20%              1.10%           4.60%
#
#   Centennial Scarborough Church-Yonge Corridor Clairlea-Birchmount  \
# 0                    133                    75                 120
# 1         No Designation        No Designation      No Designation
# 2                 13,362                31,340              26,984
# 3                 13,093                28,349              24,770
# 4                  2.10%                10.60%               8.90%
#
#      Clanton Park      Cliffcrest Corso Italia-Davenport        Danforth  \
# 0              33             123                     92              66
# 1  No Designation  No Designation         No Designation  No Designation
# 2          16,472          15,935                 14,133           9,666
# 3          14,612          15,703                 13,743           9,444
# 4          12.70%           1.50%                  2.80%           2.40%
#
#   Danforth East York Don Valley Village             Dorset Park  \
# 0                 59                 47                     126
# 1     No Designation     No Designation  Emerging Neighbourhood
# 2             17,180             27,051                  25,003
# 3             16,712             26,739                  24,363
# 4              2.80%              1.20%                   2.60%
#
#   Dovercourt-Wallace Emerson-Junction Downsview-Roding-CFB  Dufferin Grove  \
# 0                                  93                   26              83
# 1                      No Designation                  NIA  No Designation
# 2                              36,625               35,052          11,785
# 3                              34,631               34,659          11,449
# 4                               5.80%                1.10%           2.90%
#
#   East End-Danforth Edenbridge-Humber Valley Eglinton East Elms-Old Rexdale  \
# 0                62                        9           138                5
# 1    No Designation           No Designation           NIA              NIA
# 2            21,381                   15,535        22,776            9,456
# 3            20,839                   14,943        22,829            9,550
# 4             2.60%                    4.00%        -0.20%           -1.00%
#
#       Englemount-Lawrence Eringate-Centennial-West Deane Etobicoke West Mall  \
# 0                      32                             11                  13
# 1  Emerging Neighbourhood                 No Designation      No Designation
# 2                  22,372                         18,588              11,848
# 3                  22,086                         18,810              10,927
# 4                   1.30%                         -1.20%               8.40%
#
#   Flemingdon Park Forest Hill North Forest Hill South Glenfield-Jane Heights  \
# 0              44               102               101                     25
# 1             NIA    No Designation    No Designation                    NIA
# 2          21,933            12,806            10,732                 30,491
# 3          22,168            12,474            10,926                 31,390
# 4          -1.10%             2.70%            -1.80%                 -2.90%
#
#   Greenwood-Coxwell       Guildwood      Henry Farm High Park North  \
# 0                65             140              53              88
# 1    No Designation  No Designation  No Designation  No Designation
# 2            14,417           9,917          15,723          22,162
# 3            14,083           9,816          11,333          21,292
# 4             2.40%           1.00%          38.70%           4.10%
#
#   High Park-Swansea  Highland Creek Hillcrest Village  \
# 0                87             134                48
# 1    No Designation  No Designation    No Designation
# 2            23,925          12,494            16,934
# 3            21,740          13,097            17,656
# 4            10.10%          -4.60%            -4.10%
#
#   Humber Heights-Westmount Humber Summit Humbermede Humewood-Cedarvale  \
# 0                        8            21         22                106
# 1   Emerging Neighbourhood           NIA        NIA     No Designation
# 2                   10,948        12,416     15,545             14,365
# 3                   10,583        12,525     15,853             14,108
# 4                    3.40%        -0.90%     -1.90%              1.80%
#
#   Ionview Islington-City Centre West   Junction Area Keelesdale-Eglinton West  \
# 0     125                         14              90                      110
# 1     NIA             No Designation  No Designation                      NIA
# 2  13,641                     43,965          14,366                   11,058
# 3  13,091                     38,084          14,027                   10,638
# 4   4.20%                     15.40%           2.40%                    3.90%
#
#   Kennedy Park Kensington-Chinatown Kingsview Village-The Westway  \
# 0          124                   78                             6
# 1          NIA       No Designation                           NIA
# 2       17,123               17,945                        22,000
# 3       17,058               18,495                        21,723
# 4        0.40%               -3.00%                         1.30%
#
#    Kingsway South Lambton Baby Point              L'Amoreaux Lansing-Westgate  \
# 0              15                114                     117               38
# 1  No Designation     No Designation  Emerging Neighbourhood   No Designation
# 2           9,271              7,985                  43,993           16,164
# 3           9,170              7,921                  44,919           14,642
# 4           1.10%              0.80%                  -2.10%           10.40%
#
#   Lawrence Park North Lawrence Park South Leaside-Bennington Little Portugal  \
# 0                 105                 103                 56              84
# 1      No Designation      No Designation     No Designation  No Designation
# 2              14,607              15,179             16,828          15,559
# 3              14,541              15,070             17,011          12,050
# 4               0.50%               0.70%             -1.10%          29.10%
#
#       Long Branch                 Malvern      Maple Leaf   Markland Wood  \
# 0              19                     132              29              12
# 1  No Designation  Emerging Neighbourhood  No Designation  No Designation
# 2          10,084                  43,794          10,111          10,554
# 3           9,632                  45,086          10,197          10,436
# 4           4.70%                  -2.90%          -0.80%           1.10%
#
#          Milliken Mimico (includes Humber Bay Shores) Morningside  \
# 0             130                                  17         135
# 1  No Designation                      No Designation         NIA
# 2          26,572                              33,964      17,455
# 3          27,167                              26,541      17,587
# 4          -2.20%                              28.00%      -0.80%
#
#         Moss Park Mount Dennis Mount Olive-Silverstone-Jamestown  \
# 0              73          115                                 2
# 1  No Designation          NIA                               NIA
# 2          20,506       13,593                            32,954
# 3          16,306       13,145                            32,788
# 4          25.80%        3.40%                             0.50%
#
#   Mount Pleasant East Mount Pleasant West     New Toronto Newtonbrook East  \
# 0                  99                 104              18               50
# 1      No Designation      No Designation  No Designation   No Designation
# 2              16,775              29,658          11,463           16,097
# 3              15,982              28,593          10,900           16,423
# 4               5.00%               3.70%           5.20%           -2.00%
#
#   Newtonbrook West         Niagara North Riverdale North St. James Town  \
# 0               36              82              68                   74
# 1   No Designation  No Designation  No Designation       No Designation
# 2           23,831          31,180          11,916               18,615
# 3           23,052          21,274          12,191               17,832
# 4            3.40%          46.60%          -2.30%                4.40%
#
#   Oakridge Oakwood Village O'Connor-Parkview   Old East York  \
# 0      121             107                54              58
# 1      NIA  No Designation    No Designation  No Designation
# 2   13,845          21,210            18,675           9,233
# 3   13,497          21,073            18,316           9,118
# 4    2.60%           0.70%             2.00%           1.30%
#
#   Palmerston-Little Italy Parkwoods-Donalda Pelmo Park-Humberlea  \
# 0                      80                45                   23
# 1          No Designation    No Designation       No Designation
# 2                  13,826            34,805               10,722
# 3                  13,746            34,617                8,710
# 4                   0.60%             0.50%               23.10%
#
#   Playter Estates-Danforth   Pleasant View Princess-Rosethorn Regent Park  \
# 0                       67              46                 10          72
# 1           No Designation  No Designation     No Designation         NIA
# 2                    7,804          15,818             11,051      10,803
# 3                    7,653          16,144             11,197      10,007
# 4                    2.00%          -2.00%             -1.30%       8.00%
#
#   Rexdale-Kipling Rockcliffe-Smythe    Roncesvalles Rosedale-Moore Park  \
# 0               4               111              86                  98
# 1  No Designation               NIA  No Designation      No Designation
# 2          10,529            22,246          14,974              20,923
# 3          10,488            22,267          15,050              20,631
# 4           0.40%            -0.10%          -0.50%               1.40%
#
#             Rouge Runnymede-Bloor West Village  Rustic Scarborough Village  \
# 0             131                           89      28                 139
# 1  No Designation               No Designation     NIA                 NIA
# 2          46,496                       10,070   9,941              16,724
# 3          45,912                        9,632   9,951              16,609
# 4           1.30%                        4.50%  -0.10%               0.70%
#
#   South Parkdale South Riverdale St.Andrew-Windfields                 Steeles  \
# 0             85              70                   40                     116
# 1            NIA  No Designation       No Designation  Emerging Neighbourhood
# 2         21,849          27,876               17,812                  24,623
# 3         21,251          25,642               17,958                  25,017
# 4          2.80%           8.70%               -0.80%                  -1.60%
#
#   Stonegate-Queensway Tam O'Shanter-Sullivan Taylor-Massey     The Beaches  \
# 0                  16                    118            61              63
# 1      No Designation         No Designation           NIA  No Designation
# 2              25,051                 27,446        15,683          21,567
# 3              24,691                 27,398        15,594          21,130
# 4               1.50%                  0.20%         0.60%           2.10%
#
#   Thistletown-Beaumond Heights Thorncliffe Park Trinity-Bellwoods  \
# 0                            3               55                81
# 1                          NIA              NIA    No Designation
# 2                       10,360           21,108            16,556
# 3                       10,138           19,225            16,802
# 4                        2.20%            9.80%            -1.50%
#
#        University Victoria Village Waterfront Communities-The Island  \
# 0              79               43                                77
# 1  No Designation              NIA                    No Designation
# 2           7,607           17,510                            65,913
# 3           7,782           17,182                            43,361
# 4          -2.20%            1.90%                            52.00%
#
#   West Hill West Humber-Clairville     Westminster-Branson  Weston  \
# 0       136                      1                      35     113
# 1       NIA         No Designation  Emerging Neighbourhood     NIA
# 2    27,392                 33,312                  26,274  17,992
# 3    26,547                 34,100                  25,446  18,170
# 4     3.20%                 -2.30%                   3.30%  -1.00%
#
#   Weston-Pelham Park Wexford/Maryvale Willowdale East Willowdale West  \
# 0                 91              119              51              37
# 1                NIA   No Designation  No Designation  No Designation
# 2             11,098           27,917          50,434          16,936
# 3             12,010           27,018          45,041          15,004
# 4             -7.60%            3.30%          12.00%          12.90%
#
#   Willowridge-Martingrove-Richview  Woburn Woodbine Corridor Woodbine-Lumsden  \
# 0                                7     137                64               60
# 1                   No Designation     NIA    No Designation   No Designation
# 2                           22,156  53,485            12,541            7,865
# 3                           21,343  53,350            11,703            7,826
# 4                            3.80%   0.30%             7.20%            0.50%
#
#          Wychwood  Yonge-Eglinton  Yonge-St.Clair York University Heights  \
# 0              94             100              97                      27
# 1  No Designation  No Designation  No Designation                     NIA
# 2          14,349          11,817          12,528                  27,593
# 3          13,986          10,578          11,652                  27,713
# 4           2.60%          11.70%           7.50%                  -0.40%
#
#        Yorkdale-Glen Park
# 0                      31
# 1  Emerging Neighbourhood
# 2                  14,804
# 3                  14,687
# 4                   0.80%

# %% [markdown]
# ### 2. After review the raw Census data. We decided to take following items.
# - Neighbourhood code
# - Children Population
# - Youth Population
# - Household Income After Tax
# - Population holding Bachelor's degree

# %%
df_family_info = df_census.loc[df_census.index[[0, 9, 10, 1026, 1709]]]
#df_family_info.applymap(atof)
df_family_info.head()
# Out:
#                        Category                                   Topic  \
# 0     Neighbourhood Information               Neighbourhood Information
# 9                    Population                     Age characteristics
# 10                   Population                     Age characteristics
# 1026                     Income            Income of households in 2015
# 1709                  Education  Highest certificate, diploma or degree
#
#                          Data Source  \
# 0                    City of Toronto
# 9     Census Profile 98-316-X2016001
# 10    Census Profile 98-316-X2016001
# 1026  Census Profile 98-316-X2016001
# 1709  Census Profile 98-316-X2016001
#
#                                          Characteristic City of Toronto  \
# 0                                  Neighbourhood Number             NaN
# 9                                 Children (0-14 years)         398,135
# 10                                  Youth (15-24 years)         340,270
# 1026    Average after-tax income of households in 20...          81,495
# 1709                                  Bachelor's degree          534610
#
#      Agincourt North Agincourt South-Malvern West Alderwood    Annex  \
# 0                129                          128        20       95
# 9              3,840                        3,075     1,760    2,360
# 10             3,705                        3,360     1,235    3,750
# 1026         427,037                      278,390   168,602  792,507
# 1709            4380                         4210      1660     9135
#
#      Banbury-Don Mills Bathurst Manor Bay Street Corridor Bayview Village  \
# 0                   42             34                  76              52
# 9                3,605          2,325               1,695           2,415
# 10               2,730          1,940               6,860           2,505
# 1026           493,486        251,583             352,218         354,894
# 1709              6500           3075                8370            6055
#
#      Bayview Woods-Steeles Bedford Park-Nortown Beechborough-Greenbrook  \
# 0                       49                   39                     112
# 9                    1,515                4,555                   1,120
# 10                   1,635                3,210                     855
# 1026               253,036              720,203                 109,880
# 1709                  3060                 5655                     445
#
#       Bendale Birchcliffe-Cliffside Black Creek Blake-Jones  \
# 0         127                   122          24          69
# 9       4,550                 3,345       4,600       1,405
# 10      4,605                 2,440       3,290         885
# 1026  326,482               369,161     261,560     154,132
# 1709     4550                  3470        1235        1550
#
#      Briar Hill-Belgravia Bridle Path-Sunnybrook-York Mills Broadview North  \
# 0                     108                                41              57
# 9                   1,855                             1,435           1,470
# 10                  1,655                             1,425           1,040
# 1026              190,243                         1,392,010         126,349
# 1709                 2360                              2585            2215
#
#      Brookhaven-Amesbury Cabbagetown-South St. James Town Caledonia-Fairbank  \
# 0                     30                               71                109
# 9                  3,360                              800              1,490
# 10                 2,460                            1,035              1,220
# 1026             176,688                          301,145            132,879
# 1709                1435                             2925                850
#
#      Casa Loma Centennial Scarborough Church-Yonge Corridor  \
# 0           96                    133                    75
# 9        1,200                  2,150                 1,260
# 10       1,080                  1,850                 5,060
# 1026   545,338                215,135               443,734
# 1709      3315                   2925                 10405
#
#      Clairlea-Birchmount Clanton Park Cliffcrest Corso Italia-Davenport  \
# 0                    120           33        123                     92
# 9                  4,565        2,765      2,575                  1,910
# 10                 3,495        1,910      2,145                  1,545
# 1026             350,777      168,893    248,846                304,000
# 1709                3825         3495       2455                   2135
#
#      Danforth Danforth East York Don Valley Village Dorset Park  \
# 0          66                 59                 47         126
# 9       1,675              3,020              4,065       4,250
# 10        920              1,450              3,280       3,155
# 1026  260,052            334,260            414,411     251,476
# 1709     2090               3350               5995        3485
#
#      Dovercourt-Wallace Emerson-Junction Downsview-Roding-CFB Dufferin Grove  \
# 0                                     93                   26             83
# 9                                  4,480                5,725          1,285
# 10                                 3,925                4,340          1,065
# 1026                             594,477              562,794        128,586
# 1709                                7085                 3350           2590
#
#      East End-Danforth Edenbridge-Humber Valley Eglinton East  \
# 0                   62                        9           138
# 9                3,735                    2,120         4,180
# 10               2,210                    1,805         3,130
# 1026           304,010                  441,052       343,031
# 1709              4430                     3155          2575
#
#      Elms-Old Rexdale Englemount-Lawrence Eringate-Centennial-West Deane  \
# 0                   5                  32                             11
# 9               1,805               4,805                          2,635
# 10              1,440               3,030                          2,405
# 1026          123,119             293,189                        352,269
# 1709              820                3730                           3360
#
#      Etobicoke West Mall Flemingdon Park Forest Hill North Forest Hill South  \
# 0                     13              44               102               101
# 9                  1,695           4,385             2,060             1,365
# 10                 1,460           3,060             1,500             1,355
# 1026             132,460         261,233           258,469           784,645
# 1709                1810            3265              3015              2900
#
#      Glenfield-Jane Heights Greenwood-Coxwell Guildwood Henry Farm  \
# 0                        25                65       140         53
# 9                     5,790             2,460     1,295      2,505
# 10                    4,520             1,305     1,065      2,330
# 1026                410,012           216,423   177,062    202,357
# 1709                   1610              3045      1785       3985
#
#      High Park North High Park-Swansea Highland Creek Hillcrest Village  \
# 0                 88                87            134                48
# 9              2,850             3,540          1,545             2,115
# 10             1,890             2,125          1,925             2,170
# 1026         496,958           483,620        196,620           298,716
# 1709            5975              6390           2150              3980
#
#      Humber Heights-Westmount Humber Summit Humbermede Humewood-Cedarvale  \
# 0                           8            21         22                106
# 9                       1,450         2,155      2,945              2,165
# 10                      1,140         1,720      2,225              1,610
# 1026                  238,655       202,677    184,459            289,910
# 1709                     1515          1005       1370               3505
#
#       Ionview Islington-City Centre West Junction Area  \
# 0         125                         14            90
# 9       2,310                      5,820         2,190
# 10      1,645                      4,695         1,465
# 1026  169,046                    854,623       310,473
# 1709     1670                       9970          3250
#
#      Keelesdale-Eglinton West Kennedy Park Kensington-Chinatown  \
# 0                         110          124                   78
# 9                       1,610        2,775                1,315
# 10                      1,430        2,175                3,350
# 1026                  184,802      229,390              222,404
# 1709                      835         2035                 4070
#
#      Kingsview Village-The Westway Kingsway South Lambton Baby Point  \
# 0                                6             15                114
# 9                            4,240          1,580              1,695
# 10                           3,020          1,100                905
# 1026                       272,950        900,624            214,945
# 1709                          2540           2605               1660
#
#      L'Amoreaux Lansing-Westgate Lawrence Park North Lawrence Park South  \
# 0           117               38                 105                 103
# 9         6,120            2,420               3,280               2,845
# 10        5,730            2,105               1,670               2,095
# 1026    529,383          356,122             470,908           1,216,585
# 1709       6920             4400                4140                4315
#
#      Leaside-Bennington Little Portugal Long Branch  Malvern Maple Leaf  \
# 0                    56              84          19      132         29
# 9                 3,285           1,400       1,335    7,910      1,500
# 10                2,175           1,605       1,130    6,620      1,265
# 1026            841,619         202,912     137,480  533,202    144,062
# 1709               4665            4010        1735     5465       1310
#
#      Markland Wood Milliken Mimico (includes Humber Bay Shores) Morningside  \
# 0               12      130                                  17         135
# 9            1,340    3,675                               3,505       2,880
# 10           1,165    3,195                               3,010       2,690
# 1026       195,412  525,507                             583,422     272,837
# 1709          2390     3700                                7560        2255
#
#      Moss Park Mount Dennis Mount Olive-Silverstone-Jamestown  \
# 0           73          115                                 2
# 9        1,540        2,395                             7,090
# 10       2,060        1,815                             5,240
# 1026   170,813      164,344                           360,648
# 1709      5480         1045                              3015
#
#      Mount Pleasant East Mount Pleasant West New Toronto Newtonbrook East  \
# 0                     99                 104          18               50
# 9                  2,980               2,380       1,610            1,585
# 10                 1,705               2,520       1,390            2,185
# 1026             348,357             443,047     188,819          335,768
# 1709                4720                9275        1990             4290
#
#      Newtonbrook West  Niagara North Riverdale North St. James Town Oakridge  \
# 0                  36       82              68                   74      121
# 9               2,810    2,055           1,960                2,290    2,865
# 10              3,325    2,415           1,170                2,265    1,680
# 1026          260,415  369,683         318,764              144,164  134,303
# 1709             5030    11835            3030                 4010     1660
#
#      Oakwood Village O'Connor-Parkview Old East York Palmerston-Little Italy  \
# 0                107                54            58                      80
# 9              3,130             3,110         1,470                   1,280
# 10             2,275             2,385           915                   1,465
# 1026         267,062           354,525       257,522                 347,339
# 1709            3270              2735          1685                    3805
#
#      Parkwoods-Donalda Pelmo Park-Humberlea Playter Estates-Danforth  \
# 0                   45                   23                       67
# 9                5,840                1,745                    1,150
# 10               4,680                1,370                      735
# 1026           623,453              154,568                  194,189
# 1709              6105                 1220                     1980
#
#      Pleasant View Princess-Rosethorn Regent Park Rexdale-Kipling  \
# 0               46                 10          72               4
# 9            2,050              1,770       1,635           1,640
# 10           2,080              1,580       1,775           1,355
# 1026       219,209            538,736     103,250         134,305
# 1709          3090               2755        2060            1185
#
#      Rockcliffe-Smythe Roncesvalles Rosedale-Moore Park    Rouge  \
# 0                  111           86                  98      131
# 9                3,505        2,300               2,625    7,960
# 10               2,740        1,305               2,185    6,700
# 1026           295,358      377,518           1,413,132  729,154
# 1709              1930         3435                6010     6765
#
#      Runnymede-Bloor West Village   Rustic Scarborough Village South Parkdale  \
# 0                              89       28                 139             85
# 9                           2,050    1,940               3,365          2,115
# 10                            960    1,405               2,360          2,275
# 1026                      223,885  113,995             185,967        258,500
# 1709                         2455      585                1810           4210
#
#      South Riverdale St.Andrew-Windfields  Steeles Stonegate-Queensway  \
# 0                 70                   40      116                  16
# 9              3,975                2,645    3,150               4,060
# 10             2,445                2,540    2,685               2,495
# 1026         662,651              649,291  363,045             516,575
# 1709            6305                 4200     4320                5335
#
#      Tam O'Shanter-Sullivan Taylor-Massey The Beaches  \
# 0                       118            61          63
# 9                     3,885         2,950       3,825
# 10                    3,225         1,690       2,075
# 1026                475,647       102,259     659,192
# 1709                   4830          2435        5705
#
#      Thistletown-Beaumond Heights Thorncliffe Park Trinity-Bellwoods  \
# 0                               3               55                81
# 9                           1,730            5,600             1,745
# 10                          1,410            2,455             1,630
# 1026                      140,050          195,114           333,954
# 1709                         1175             3125              3515
#
#      University Victoria Village Waterfront Communities-The Island West Hill  \
# 0            79               43                                77       136
# 9           565            2,630                             3,650     4,635
# 10        1,485            2,030                             7,840     3,950
# 1026    197,072          171,271                           662,333   316,750
# 1709       1965             2630                             27280      3015
#
#      West Humber-Clairville Westminster-Branson   Weston Weston-Pelham Park  \
# 0                         1                  35      113                 91
# 9                     5,060               3,440    3,100              1,675
# 10                    5,445               3,355    2,225              1,415
# 1026                426,156             332,776  171,044            127,491
# 1709                   4245                5195     1705               1130
#
#      Wexford/Maryvale Willowdale East Willowdale West  \
# 0                 119              51              37
# 9               4,215           5,920           1,785
# 10              3,650           6,940           2,230
# 1026          336,503         572,155         272,986
# 1709             3770           15435            4700
#
#      Willowridge-Martingrove-Richview   Woburn Woodbine Corridor  \
# 0                                   7      137                64
# 9                               3,555    9,625             2,325
# 10                              2,625    7,660             1,035
# 1026                          412,302  629,030           240,272
# 1709                             3655     7575              2795
#
#      Woodbine-Lumsden Wychwood Yonge-Eglinton Yonge-St.Clair  \
# 0                  60       94            100             97
# 9               1,165    1,860          1,800          1,210
# 10                675    1,320          1,225            920
# 1026          147,462  239,484        222,648        541,217
# 1709             1435     2770           3625           3720
#
#      York University Heights Yorkdale-Glen Park
# 0                         27                 31
# 9                      4,045              1,960
# 10                     4,750              1,870
# 1026                 302,358            213,860
# 1709                    3910               1595

# %% [markdown]
# ### 3. Remove certain columns which are not used in our data analysis

# %%
#df_census.columns.values
df_family_info.drop(columns=['Category', 'Topic', 'Data Source', 'Characteristic', 'City of Toronto'], axis=1, inplace=True)
df_family_info.applymap(atof)
df_family_info.head()
# Out:
#      Agincourt North Agincourt South-Malvern West Alderwood    Annex  \
# 0                129                          128        20       95
# 9              3,840                        3,075     1,760    2,360
# 10             3,705                        3,360     1,235    3,750
# 1026         427,037                      278,390   168,602  792,507
# 1709            4380                         4210      1660     9135
#
#      Banbury-Don Mills Bathurst Manor Bay Street Corridor Bayview Village  \
# 0                   42             34                  76              52
# 9                3,605          2,325               1,695           2,415
# 10               2,730          1,940               6,860           2,505
# 1026           493,486        251,583             352,218         354,894
# 1709              6500           3075                8370            6055
#
#      Bayview Woods-Steeles Bedford Park-Nortown Beechborough-Greenbrook  \
# 0                       49                   39                     112
# 9                    1,515                4,555                   1,120
# 10                   1,635                3,210                     855
# 1026               253,036              720,203                 109,880
# 1709                  3060                 5655                     445
#
#       Bendale Birchcliffe-Cliffside Black Creek Blake-Jones  \
# 0         127                   122          24          69
# 9       4,550                 3,345       4,600       1,405
# 10      4,605                 2,440       3,290         885
# 1026  326,482               369,161     261,560     154,132
# 1709     4550                  3470        1235        1550
#
#      Briar Hill-Belgravia Bridle Path-Sunnybrook-York Mills Broadview North  \
# 0                     108                                41              57
# 9                   1,855                             1,435           1,470
# 10                  1,655                             1,425           1,040
# 1026              190,243                         1,392,010         126,349
# 1709                 2360                              2585            2215
#
#      Brookhaven-Amesbury Cabbagetown-South St. James Town Caledonia-Fairbank  \
# 0                     30                               71                109
# 9                  3,360                              800              1,490
# 10                 2,460                            1,035              1,220
# 1026             176,688                          301,145            132,879
# 1709                1435                             2925                850
#
#      Casa Loma Centennial Scarborough Church-Yonge Corridor  \
# 0           96                    133                    75
# 9        1,200                  2,150                 1,260
# 10       1,080                  1,850                 5,060
# 1026   545,338                215,135               443,734
# 1709      3315                   2925                 10405
#
#      Clairlea-Birchmount Clanton Park Cliffcrest Corso Italia-Davenport  \
# 0                    120           33        123                     92
# 9                  4,565        2,765      2,575                  1,910
# 10                 3,495        1,910      2,145                  1,545
# 1026             350,777      168,893    248,846                304,000
# 1709                3825         3495       2455                   2135
#
#      Danforth Danforth East York Don Valley Village Dorset Park  \
# 0          66                 59                 47         126
# 9       1,675              3,020              4,065       4,250
# 10        920              1,450              3,280       3,155
# 1026  260,052            334,260            414,411     251,476
# 1709     2090               3350               5995        3485
#
#      Dovercourt-Wallace Emerson-Junction Downsview-Roding-CFB Dufferin Grove  \
# 0                                     93                   26             83
# 9                                  4,480                5,725          1,285
# 10                                 3,925                4,340          1,065
# 1026                             594,477              562,794        128,586
# 1709                                7085                 3350           2590
#
#      East End-Danforth Edenbridge-Humber Valley Eglinton East  \
# 0                   62                        9           138
# 9                3,735                    2,120         4,180
# 10               2,210                    1,805         3,130
# 1026           304,010                  441,052       343,031
# 1709              4430                     3155          2575
#
#      Elms-Old Rexdale Englemount-Lawrence Eringate-Centennial-West Deane  \
# 0                   5                  32                             11
# 9               1,805               4,805                          2,635
# 10              1,440               3,030                          2,405
# 1026          123,119             293,189                        352,269
# 1709              820                3730                           3360
#
#      Etobicoke West Mall Flemingdon Park Forest Hill North Forest Hill South  \
# 0                     13              44               102               101
# 9                  1,695           4,385             2,060             1,365
# 10                 1,460           3,060             1,500             1,355
# 1026             132,460         261,233           258,469           784,645
# 1709                1810            3265              3015              2900
#
#      Glenfield-Jane Heights Greenwood-Coxwell Guildwood Henry Farm  \
# 0                        25                65       140         53
# 9                     5,790             2,460     1,295      2,505
# 10                    4,520             1,305     1,065      2,330
# 1026                410,012           216,423   177,062    202,357
# 1709                   1610              3045      1785       3985
#
#      High Park North High Park-Swansea Highland Creek Hillcrest Village  \
# 0                 88                87            134                48
# 9              2,850             3,540          1,545             2,115
# 10             1,890             2,125          1,925             2,170
# 1026         496,958           483,620        196,620           298,716
# 1709            5975              6390           2150              3980
#
#      Humber Heights-Westmount Humber Summit Humbermede Humewood-Cedarvale  \
# 0                           8            21         22                106
# 9                       1,450         2,155      2,945              2,165
# 10                      1,140         1,720      2,225              1,610
# 1026                  238,655       202,677    184,459            289,910
# 1709                     1515          1005       1370               3505
#
#       Ionview Islington-City Centre West Junction Area  \
# 0         125                         14            90
# 9       2,310                      5,820         2,190
# 10      1,645                      4,695         1,465
# 1026  169,046                    854,623       310,473
# 1709     1670                       9970          3250
#
#      Keelesdale-Eglinton West Kennedy Park Kensington-Chinatown  \
# 0                         110          124                   78
# 9                       1,610        2,775                1,315
# 10                      1,430        2,175                3,350
# 1026                  184,802      229,390              222,404
# 1709                      835         2035                 4070
#
#      Kingsview Village-The Westway Kingsway South Lambton Baby Point  \
# 0                                6             15                114
# 9                            4,240          1,580              1,695
# 10                           3,020          1,100                905
# 1026                       272,950        900,624            214,945
# 1709                          2540           2605               1660
#
#      L'Amoreaux Lansing-Westgate Lawrence Park North Lawrence Park South  \
# 0           117               38                 105                 103
# 9         6,120            2,420               3,280               2,845
# 10        5,730            2,105               1,670               2,095
# 1026    529,383          356,122             470,908           1,216,585
# 1709       6920             4400                4140                4315
#
#      Leaside-Bennington Little Portugal Long Branch  Malvern Maple Leaf  \
# 0                    56              84          19      132         29
# 9                 3,285           1,400       1,335    7,910      1,500
# 10                2,175           1,605       1,130    6,620      1,265
# 1026            841,619         202,912     137,480  533,202    144,062
# 1709               4665            4010        1735     5465       1310
#
#      Markland Wood Milliken Mimico (includes Humber Bay Shores) Morningside  \
# 0               12      130                                  17         135
# 9            1,340    3,675                               3,505       2,880
# 10           1,165    3,195                               3,010       2,690
# 1026       195,412  525,507                             583,422     272,837
# 1709          2390     3700                                7560        2255
#
#      Moss Park Mount Dennis Mount Olive-Silverstone-Jamestown  \
# 0           73          115                                 2
# 9        1,540        2,395                             7,090
# 10       2,060        1,815                             5,240
# 1026   170,813      164,344                           360,648
# 1709      5480         1045                              3015
#
#      Mount Pleasant East Mount Pleasant West New Toronto Newtonbrook East  \
# 0                     99                 104          18               50
# 9                  2,980               2,380       1,610            1,585
# 10                 1,705               2,520       1,390            2,185
# 1026             348,357             443,047     188,819          335,768
# 1709                4720                9275        1990             4290
#
#      Newtonbrook West  Niagara North Riverdale North St. James Town Oakridge  \
# 0                  36       82              68                   74      121
# 9               2,810    2,055           1,960                2,290    2,865
# 10              3,325    2,415           1,170                2,265    1,680
# 1026          260,415  369,683         318,764              144,164  134,303
# 1709             5030    11835            3030                 4010     1660
#
#      Oakwood Village O'Connor-Parkview Old East York Palmerston-Little Italy  \
# 0                107                54            58                      80
# 9              3,130             3,110         1,470                   1,280
# 10             2,275             2,385           915                   1,465
# 1026         267,062           354,525       257,522                 347,339
# 1709            3270              2735          1685                    3805
#
#      Parkwoods-Donalda Pelmo Park-Humberlea Playter Estates-Danforth  \
# 0                   45                   23                       67
# 9                5,840                1,745                    1,150
# 10               4,680                1,370                      735
# 1026           623,453              154,568                  194,189
# 1709              6105                 1220                     1980
#
#      Pleasant View Princess-Rosethorn Regent Park Rexdale-Kipling  \
# 0               46                 10          72               4
# 9            2,050              1,770       1,635           1,640
# 10           2,080              1,580       1,775           1,355
# 1026       219,209            538,736     103,250         134,305
# 1709          3090               2755        2060            1185
#
#      Rockcliffe-Smythe Roncesvalles Rosedale-Moore Park    Rouge  \
# 0                  111           86                  98      131
# 9                3,505        2,300               2,625    7,960
# 10               2,740        1,305               2,185    6,700
# 1026           295,358      377,518           1,413,132  729,154
# 1709              1930         3435                6010     6765
#
#      Runnymede-Bloor West Village   Rustic Scarborough Village South Parkdale  \
# 0                              89       28                 139             85
# 9                           2,050    1,940               3,365          2,115
# 10                            960    1,405               2,360          2,275
# 1026                      223,885  113,995             185,967        258,500
# 1709                         2455      585                1810           4210
#
#      South Riverdale St.Andrew-Windfields  Steeles Stonegate-Queensway  \
# 0                 70                   40      116                  16
# 9              3,975                2,645    3,150               4,060
# 10             2,445                2,540    2,685               2,495
# 1026         662,651              649,291  363,045             516,575
# 1709            6305                 4200     4320                5335
#
#      Tam O'Shanter-Sullivan Taylor-Massey The Beaches  \
# 0                       118            61          63
# 9                     3,885         2,950       3,825
# 10                    3,225         1,690       2,075
# 1026                475,647       102,259     659,192
# 1709                   4830          2435        5705
#
#      Thistletown-Beaumond Heights Thorncliffe Park Trinity-Bellwoods  \
# 0                               3               55                81
# 9                           1,730            5,600             1,745
# 10                          1,410            2,455             1,630
# 1026                      140,050          195,114           333,954
# 1709                         1175             3125              3515
#
#      University Victoria Village Waterfront Communities-The Island West Hill  \
# 0            79               43                                77       136
# 9           565            2,630                             3,650     4,635
# 10        1,485            2,030                             7,840     3,950
# 1026    197,072          171,271                           662,333   316,750
# 1709       1965             2630                             27280      3015
#
#      West Humber-Clairville Westminster-Branson   Weston Weston-Pelham Park  \
# 0                         1                  35      113                 91
# 9                     5,060               3,440    3,100              1,675
# 10                    5,445               3,355    2,225              1,415
# 1026                426,156             332,776  171,044            127,491
# 1709                   4245                5195     1705               1130
#
#      Wexford/Maryvale Willowdale East Willowdale West  \
# 0                 119              51              37
# 9               4,215           5,920           1,785
# 10              3,650           6,940           2,230
# 1026          336,503         572,155         272,986
# 1709             3770           15435            4700
#
#      Willowridge-Martingrove-Richview   Woburn Woodbine Corridor  \
# 0                                   7      137                64
# 9                               3,555    9,625             2,325
# 10                              2,625    7,660             1,035
# 1026                          412,302  629,030           240,272
# 1709                             3655     7575              2795
#
#      Woodbine-Lumsden Wychwood Yonge-Eglinton Yonge-St.Clair  \
# 0                  60       94            100             97
# 9               1,165    1,860          1,800          1,210
# 10                675    1,320          1,225            920
# 1026          147,462  239,484        222,648        541,217
# 1709             1435     2770           3625           3720
#
#      York University Heights Yorkdale-Glen Park
# 0                         27                 31
# 9                      4,045              1,960
# 10                     4,750              1,870
# 1026                 302,358            213,860
# 1709                    3910               1595

# %% [markdown]
# **Week 2 work continued here for Census Dataset**<br>
# ### 4. Transpose the original Pandas DataFrame for data analyzing items with 140 neighbourhoods.

# %%
# Transpose the dataframe
df_family_info_t = df_family_info.T
#df_family_info_t.head()
df_family_info_t.shape
# Out:
# (140, 5)

# %%
#df_family_info_t.columns=df_family_info_t.iloc[0]
df_family_info_t.reset_index(inplace = True)
df_family_info_t.columns=["Neighbourhood", "Neighbourhood_Code", "Children", "Youth", "Avg_Household_Income", "College_Educated"]
df_family_info_t.head()
# Out:
#                   Neighbourhood Neighbourhood_Code Children  Youth  \
# 0               Agincourt North                129    3,840  3,705
# 1  Agincourt South-Malvern West                128    3,075  3,360
# 2                     Alderwood                 20    1,760  1,235
# 3                         Annex                 95    2,360  3,750
# 4             Banbury-Don Mills                 42    3,605  2,730
#
#   Avg_Household_Income College_Educated
# 0              427,037             4380
# 1              278,390             4210
# 2              168,602             1660
# 3              792,507             9135
# 4              493,486             6500

# %% [markdown]
# ### 5. Convert all string type numeric fields into integer type for math operations

# %%
df_family_info_t["Children"] = df_family_info_t["Children"].str.replace(",","").astype(int)
df_family_info_t["Youth"] = df_family_info_t["Youth"].str.replace(",","").astype(int)
df_family_info_t["Avg_Household_Income"] = df_family_info_t["Avg_Household_Income"].str.replace(",","").astype(int)
df_family_info_t["College_Educated"] = df_family_info_t["College_Educated"].str.replace(",","").astype(int)

df_family_info_t = df_family_info_t.astype({'Neighbourhood_Code':int})
df_family_info_t.sort_values(['Neighbourhood_Code'], ascending=True).head()
# Out:
#                          Neighbourhood  Neighbourhood_Code  Children  Youth  \
# 124             West Humber-Clairville                   1      5060   5445
# 81   Mount Olive-Silverstone-Jamestown                   2      7090   5240
# 117       Thistletown-Beaumond Heights                   3      1730   1410
# 101                    Rexdale-Kipling                   4      1640   1355
# 38                    Elms-Old Rexdale                   5      1805   1440
#
#      Avg_Household_Income  College_Educated
# 124                426156              4245
# 81                 360648              3015
# 117                140050              1175
# 101                134305              1185
# 38                 123119               820

# %% [markdown]
# ### 6. Let us review statistic information for this DataFrame

# %%
df_family_info_t.describe()
# Out:
#        Neighbourhood_Code     Children        Youth  Avg_Household_Income  \
# count            140.0000   140.000000   140.000000          1.400000e+02
# mean              70.5000  2843.964286  2430.928571          3.512761e+05
# std               40.5586  1546.225445  1457.994778          2.309379e+05
# min                1.0000   565.000000   675.000000          1.022590e+05
# 25%               35.7500  1695.000000  1428.750000          1.953375e+05
# 50%               70.5000  2405.000000  2100.000000          2.915495e+05
# 75%              105.2500  3567.500000  3022.500000          4.305408e+05
# max              140.0000  9625.000000  7840.000000          1.413132e+06
#
#        College_Educated
# count        140.000000
# mean        3819.000000
# std         3046.742287
# min          445.000000
# 25%         2053.750000
# 50%         3257.500000
# 75%         4385.000000
# max        27280.000000

# %% [markdown]
# ### 7. Normalize data with statistic information

# %%
#Scale columns Population of Children, Youth, Household_Income after tax, and finished College Education population
#The weights scale will be used for K clustering

df_family_info_t["Children_Weight"] = df_family_info_t["Children"].divide(df_family_info_t["Children"].mean())
df_family_info_t["Youth_Weight"] = df_family_info_t["Youth"].divide(df_family_info_t["Youth"].mean)
df_family_info_t["Household_Income_Weight"] = df_family_info_t["Avg_Household_Income"].divide(df_family_info_t["Avg_Household_Income"].mean())
df_family_info_t["College_Educated_Weight"] = df_family_info_t["College_Educated"].divide(df_family_info_t["College_Educated"].mean())
df_family_info_t.head()
# Out:
#                   Neighbourhood  Neighbourhood_Code  Children  Youth  \
# 0               Agincourt North                 129      3840   3705
# 1  Agincourt South-Malvern West                 128      3075   3360
# 2                     Alderwood                  20      1760   1235
# 3                         Annex                  95      2360   3750
# 4             Banbury-Don Mills                  42      3605   2730
#
#    Avg_Household_Income  College_Educated  Children_Weight  Youth_Weight  \
# 0                427037              4380         1.350211      1.524064
# 1                278390              4210         1.081224      1.382147
# 2                168602              1660         0.618847      0.508021
# 3                792507              9135         0.829817      1.542575
# 4                493486              6500         1.267581      1.122995
#
#    Household_Income_Weight  College_Educated_Weight
# 0                 1.215673                 1.146897
# 1                 0.792511                 1.102383
# 2                 0.479970                 0.434669
# 3                 2.256080                 2.391987
# 4                 1.404838                 1.702016

# %% [markdown]
# **Here is the normalized dataset.**

# %%
df_weights_info = df_family_info_t[['Neighbourhood', 'Neighbourhood_Code', 'Children_Weight', 'Youth_Weight', 'Household_Income_Weight', 'College_Educated_Weight']]
df_weights_info.head()
# Out:
#                   Neighbourhood  Neighbourhood_Code  Children_Weight  \
# 0               Agincourt North                 129         1.350211
# 1  Agincourt South-Malvern West                 128         1.081224
# 2                     Alderwood                  20         0.618847
# 3                         Annex                  95         0.829817
# 4             Banbury-Don Mills                  42         1.267581
#
#    Youth_Weight  Household_Income_Weight  College_Educated_Weight
# 0      1.524064                 1.215673                 1.146897
# 1      1.382147                 0.792511                 1.102383
# 2      0.508021                 0.479970                 0.434669
# 3      1.542575                 2.256080                 2.391987
# 4      1.122995                 1.404838                 1.702016

# %% [markdown]
# ### 8. Dataset visualization part

# %% [markdown]
# **1. The Bar chart for 140 neighbourhoods**

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

df_weights_bar_char = df_family_info_t[['Neighbourhood', 'Children_Weight', 'Youth_Weight', 'Household_Income_Weight', 'College_Educated_Weight']]
#df_weights_bar_char.head()

ax = df_weights_bar_char.plot(kind='barh', figsize=(8, 40))
ax.set_yticklabels(df_weights_bar_char['Neighbourhood'])

#df_pc.set_index(['Interested fields'], inplace = True)
plt.title('Census Weights Chart of 140 neighbourhoods')

plt.ylabel('Neighbourhoods Weights Distribution')
plt.xlabel('Weights')
plt.show()

# %% [markdown]
# **2. Observing the corelations amoung Children, Household_Income, College_Educated weights thru the Scatter Plots**
#
# - <font color="red"><b>Red colo</b>r</font> represents Household after tax income is above the average, they may have extra money in their bank account. These families may likely to be the **Learning Center** customers.
#
# - <font color="blue"><b>Blue color</b></font> represents Household after tax income is two times over the average, they do have extra money in their bank account. These families are most likely to be the majority of  **Learning Center** customers.
#
# - <font color="green"><b>Green color</b></font> represnets Houshold after tax income is barely reached the average or less, they may be interested in some discounts programs or lower cost programes in the **Learning Center**.

# %%
#Let us create a Scatter Chart with these facts
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

'''
# Fixing random state for reproducibility
np.random.seed(19680801)

fig = plt.figure(figsize=(20, 8))

ax = fig.add_subplot(111, projection='3d')

# Function to map the colors as a list from the input list of x variables
def pltcolor(lst):
    cols=[]
    for l in lst:
        if l > 1 and l < 2:
          cols.append('red')           
        elif l >= 2:
          cols.append('blue')          
        elif l == 1:
          cols.append('black')
        else:
            cols.append('green')            
    return cols
# Create the colors list using the function above
cols=pltcolor(df_weights_bar_char["Household_Income_Weight"])

xs = df_weights_bar_char["Household_Income_Weight"] 
ys = df_weights_bar_char["College_Educated_Weight"] 
zs = df_weights_bar_char["Children_Weight"] 

ax.scatter(xs, ys, zs, c=cols, s=50)

ax.set_xlabel('Houshold_Income')
ax.set_ylabel('College_Educated')
ax.set_zlabel('Children')

plt.title("3D Visualization")
plt.show()
'''

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

fig = plt.figure(figsize=(20, 8))

#ax = fig.add_subplot(111, projection='3d')

n = len(df_weights_bar_char["Household_Income_Weight"])
X = df_weights_bar_char["Household_Income_Weight"]
Y = df_weights_bar_char["College_Educated_Weight"]
Z = df_weights_bar_char["Children_Weight"]
x1 = []
x2 = []
x3 = []
y1 = []
y2 = []
y3 = []
z1 = []
z2 = []
z3 = []

# Function to map the colors as a list from the input list of x variables
def pltcolor(lst):
    cols=[]
    i=0
    for l in lst:
        if l > 1 and l < 2:
          cols.append('red') 
          x1.append(X[i])
          y1.append(Y[i])
          z1.append(Z[i])
        elif l >= 2:
          cols.append('blue')
          x2.append(X[i])
          y2.append(Y[i])
          z2.append(Z[i])
        else:
            cols.append('green')
            x3.append(X[i])
            y3.append(Y[i])
            z3.append(Z[i])
        i = i+1
    return cols
# Create the colors list using the function above
cols=pltcolor(df_weights_bar_char["Household_Income_Weight"])


mpl.rcParams['legend.fontsize'] = 10

ax_c = fig.gca(projection='3d')

ax_c.scatter(x3, y3, z3, label='Low income family', s=50, marker='o', c='green')
ax_c.scatter(x1, y1, z1, label='Middle income family', s=50, marker='o', c='red')
ax_c.scatter(x2, y2, z2, label='Upper income family', s=50, marker='o', c='blue')

ax_c.legend(loc="upper left")

ax_c.set_xlabel('Houshold_Income')
ax_c.set_ylabel('College_Educated')
ax_c.set_zlabel('Children')

plt.title("Children-Household Income-Education Level Distribution")

plt.show()

# %%
fig = plt.figure(figsize=(20, 8))

n = len(df_weights_bar_char["Household_Income_Weight"])
X = df_weights_bar_char["Household_Income_Weight"]
Y = df_weights_bar_char["College_Educated_Weight"]
Z = df_weights_bar_char["Youth_Weight"]
x1 = []
x2 = []
x3 = []
y1 = []
y2 = []
y3 = []
z1 = []
z2 = []
z3 = []

# Function to map the colors as a list from the input list of x variables
def pltcolor(lst):
    cols=[]
    i=0
    for l in lst:
        if l >= 1 and l < 2:
          cols.append('red') 
          x1.append(X[i])
          y1.append(Y[i])
          z1.append(Z[i])
        elif l >= 2:
          cols.append('blue')
          x2.append(X[i])
          y2.append(Y[i])
          z2.append(Z[i])
        else:
            cols.append('green')
            x3.append(X[i])
            y3.append(Y[i])
            z3.append(Z[i])
        i = i+1
    return cols
# Create the colors list using the function above
cols=pltcolor(df_weights_bar_char["Household_Income_Weight"])


mpl.rcParams['legend.fontsize'] = 10

ax_y = fig.gca(projection='3d')

ax_y.scatter(x3, y3, z3, label='Low income family', s=50, marker='o', c='green')
ax_y.scatter(x1, y1, z1, label='Middle income family', s=50, marker='o', c='red')
ax_y.scatter(x2, y2, z2, label='Upper income family', s=50, marker='o', c='blue')

ax_y.legend(loc="upper left")

ax_y.set_xlabel('Houshold_Income')
ax_y.set_ylabel('College_Educated')
ax_y.set_zlabel('Youth')

plt.title("Youth-Household Income-Education Level Distribution")

plt.show()

# %% [markdown]
# **Conclusions of observations from these above 3-D Plot Charts**
#
# The Children distribution and Youth distribution are following similar distribution pattern with College Education, Household Income distribution. It gives us kind of idea, both of Children, Youth distributions follow same mathmetic model for data processing.

# %% [markdown]
# **3. Let us visualizing data trends thru following Scatter Plot charts**<br>
# **(1) the Children-Education trend**<br>
# **(2) the Youth-Education trend**<br>
# **(3) the Education-Household Income trend**<br>
# **(4) the Children-Household Income trend**<br>
# **(5) the Youth-Household Income trend**<br>

# %%
df_ch_ed = df_weights_bar_char[['College_Educated_Weight', 'Children_Weight','Household_Income_Weight']]

ax2 = df_ch_ed.plot.scatter(x='College_Educated_Weight',
                            y='Children_Weight',
                            c='Household_Income_Weight',
                            s=50,
                            colormap='viridis',
                            sharex=False)
#
plt.title('College_Educated_Weight - Children_Weight')
plt.show()

# %%
ax2.get_xlabel()
# Out:
# 'College_Educated_Weight'

# %%
df_yt_ed = df_weights_bar_char[['Youth_Weight', 'College_Educated_Weight', 'Household_Income_Weight']]
ax3 = df_yt_ed.plot.scatter(x='College_Educated_Weight',
                            y='Youth_Weight',
                            c='Household_Income_Weight',
                            colormap='viridis',
                            s=50,
                            sharex=False)
plt.title("Educate_weight - Youth_Weight")
plt.show()

# %%
df_ed_in = df_weights_bar_char[['College_Educated_Weight', 'Household_Income_Weight']]
ax4 = df_ed_in.plot.scatter(x="College_Educated_Weight",
                            y="Household_Income_Weight",
                            c="red")

# %%
import seaborn as sns
ax4_ = sns.regplot(x='Household_Income_Weight', y='College_Educated_Weight', data=df_ed_in)

# %%
df_ch_in = df_weights_bar_char[['Household_Income_Weight', 'Children_Weight']]
ax5_ = sns.regplot(x='Household_Income_Weight', y='Children_Weight', data=df_ch_in)

# %%
df_yt_in = df_weights_bar_char[['Household_Income_Weight', 'Youth_Weight']]
ax6_ = sns.regplot(x='Household_Income_Weight', y='Youth_Weight', data=df_yt_in)

# %%
df_yt_ed = df_weights_bar_char[['College_Educated_Weight', 'Youth_Weight']]
ax7_ = sns.regplot(x='College_Educated_Weight', y='Youth_Weight', data=df_yt_ed)

# %%
df_ch_ed = df_weights_bar_char[['College_Educated_Weight', 'Children_Weight']]
ax8_ = sns.regplot(x='College_Educated_Weight', y='Children_Weight', data=df_ch_ed)

# %% [markdown]
# **Conclusion of the Plots observations**
#
# From the above charts, there is positive corelation between Education level and Household income, also the Children, Youth follow the same positive corelation pattern. This discovery gives us the idead to develop the correct mathmetic model to work on this problem.

# %% [markdown]
# ### 9. Applying K-Means Clustering Classification method for all 140 neighbourhoods
#
# **(1) The input dataset is Children_Weight, Youth_Weight, Household_Income_Weights, College_Educated_Weight**

# %%
from sklearn.preprocessing import StandardScaler

#To have the better effectives of the clustering classification, the data is transformed with StandardScaler call.

df_weights_clustering = df_weights_bar_char.drop(columns=['Neighbourhood'], axis=1)
df_weights_clustering_X = StandardScaler().fit_transform(df_weights_clustering)
df_weights_clustering_X

# %%
#let us run K clustering
# set number of clusters
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=4).fit(df_weights_clustering_X)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 4, 0, 4, 4, 0, 4, 4, 0, 4], dtype=int32)

# %% [markdown]
# **(2) Merge the Clustering Labels with the DataFrame, which is the input dataset.**

# %%
df_weights_info.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
df_weights_info.head()
# Out:
#    Cluster Labels                 Neighbourhood  Neighbourhood_Code  \
# 0               4               Agincourt North                 129
# 1               4  Agincourt South-Malvern West                 128
# 2               0                     Alderwood                  20
# 3               4                         Annex                  95
# 4               4             Banbury-Don Mills                  42
#
#    Children_Weight  Youth_Weight  Household_Income_Weight  \
# 0         1.350211      1.524064                 1.215673
# 1         1.081224      1.382147                 0.792511
# 2         0.618847      0.508021                 0.479970
# 3         0.829817      1.542575                 2.256080
# 4         1.267581      1.122995                 1.404838
#
#    College_Educated_Weight
# 0                 1.146897
# 1                 1.102383
# 2                 0.434669
# 3                 2.391987
# 4                 1.702016

# %% [markdown]
# ###10. Hypothesis (Build the mathmetical model)
#
# Based in the above data visualization plots, we assumed an existing linear relation as,<br> **Complex_Score = 20% X Children_Weight + 20% X Youth_Weight + 20% X College_Educated_Weight + 40% X Houshold_Income_Weight**
#
# **Simply Represents mathmetical formula,**<br><br>
# **f(x<sub>1</sub>, x<sub>2</sub>, x<sub>3</sub>) = &#952;<sub>1</sub>x<sub>1</sub> + &#952;<sub>2</sub>x<sub>2</sub> + &#952;<sub>3</sub>x<sub>3</sub>**

# %%
#Create a complex weights equation
#complex_weight_score = Children_Weight X 20% + Youth_Weight X 20% + Avg_Household_Income_Weight X 40% + College_Educated_Weight X 20%
df_weights_info["Complex_Score"]=df_weights_info["Children_Weight"]*0.2 + df_weights_info["Youth_Weight"]*0.2 + df_weights_info["Household_Income_Weight"]*0.4 + df_weights_info["College_Educated_Weight"]*0.2 

df_weights_info.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    Cluster Labels                 Neighbourhood  Neighbourhood_Code  \
# 0               4               Agincourt North                 129
# 1               4  Agincourt South-Malvern West                 128
# 2               0                     Alderwood                  20
# 3               4                         Annex                  95
# 4               4             Banbury-Don Mills                  42
#
#    Children_Weight  Youth_Weight  Household_Income_Weight  \
# 0         1.350211      1.524064                 1.215673
# 1         1.081224      1.382147                 0.792511
# 2         0.618847      0.508021                 0.479970
# 3         0.829817      1.542575                 2.256080
# 4         1.267581      1.122995                 1.404838
#
#    College_Educated_Weight  Complex_Score
# 0                 1.146897       1.290504
# 1                 1.102383       1.030155
# 2                 0.434669       0.504295
# 3                 2.391987       1.855308
# 4                 1.702016       1.380454

# %% [markdown]
# ###11. Observing the dataset with Classification and the Complex Score - The labels corelation with the calculated Complex Score
#
# There is an existing correlation between the Complex Score value and the Clustering Labels. Except one neighbour hood - Waterfront Communities-The Island may has confilcation with our hypothesis. After certain researchs of the residents information in this area, it becaomes to be understandable. This is the area for people who may just graduated from college to stay for aboudance job opportunities. That tells us why the College_Educated_Weight is very high, but the Household_Income_Weight is not as high as other neighbour hoods.

# %%
#df_top_16 = df_weights_info.sort_values(by=['Complex_Score', 'Cluster Labels'], ascending=False).head(16)
df_top_16 = df_weights_info.sort_values(by=['Complex_Score'], ascending=False).head(16)

df_top_16
# Out:
#      Cluster Labels                        Neighbourhood  Neighbourhood_Code  \
# 122               2    Waterfront Communities-The Island                  77
# 129               2                      Willowdale East                  51
# 132               1                               Woburn                 137
# 105               1                                Rouge                 131
# 58                1           Islington-City Centre West                  14
# 104               3                  Rosedale-Moore Park                  98
# 73                1                              Malvern                 132
# 69                3                  Lawrence Park South                 103
# 16                3    Bridle Path-Sunnybrook-York Mills                  41
# 66                1                           L'Amoreaux                 117
# 3                 4                                Annex                  95
# 95                1                    Parkwoods-Donalda                  45
# 9                 4                 Bedford Park-Nortown                  39
# 32                4  Dovercourt-Wallace Emerson-Junction                  93
# 70                3                   Leaside-Bennington                  56
# 33                1                 Downsview-Roding-CFB                  26
#
#      Children_Weight  Youth_Weight  Household_Income_Weight  \
# 122         1.283404      3.225010                 1.885505
# 129         2.081575      2.854792                 1.628790
# 132         3.384318      3.150967                 1.790700
# 105         2.798875      2.756067                 2.075729
# 58          2.046414      1.931304                 2.432910
# 104         0.922996      0.898807                 4.022853
# 73          2.781294      2.723159                 1.517900
# 69          1.000352      0.861785                 3.463330
# 16          0.504571      0.586179                 3.962723
# 66          2.151899      2.357055                 1.507028
# 3           0.829817      1.542575                 2.256080
# 95          2.053446      1.925134                 1.774823
# 9           1.601617      1.320444                 2.050248
# 32          1.575246      1.614562                 1.692335
# 70          1.155063      0.894694                 2.395890
# 33          2.013010      1.785274                 1.602141
#
#      College_Educated_Weight  Complex_Score
# 122                 7.143231       3.084531
# 129                 4.041634       2.447116
# 132                 1.983504       2.420037
# 105                 1.771406       2.295561
# 58                  2.610631       2.290834
# 104                 1.573710       2.288244
# 73                  1.431003       1.994251
# 69                  1.129877       1.983735
# 16                  0.676879       1.938615
# 66                  1.811993       1.867001
# 3                   2.391987       1.855308
# 95                  1.598586       1.825362
# 9                   1.480754       1.700662
# 32                  1.855198       1.685935
# 70                  1.221524       1.612612
# 33                  0.877193       1.575952

# %% [markdown]
# Since neighbourhood **Waterfron Communities-The Island** is a special out of range spot compare to other spots. so, we move it out from our exploring vision.

# %%
df_top_16.drop(index=122, axis=0, inplace=True)
df_top_16
# Out:
#      Cluster Labels                        Neighbourhood  Neighbourhood_Code  \
# 129               2                      Willowdale East                  51
# 132               1                               Woburn                 137
# 105               1                                Rouge                 131
# 58                1           Islington-City Centre West                  14
# 104               3                  Rosedale-Moore Park                  98
# 73                1                              Malvern                 132
# 69                3                  Lawrence Park South                 103
# 16                3    Bridle Path-Sunnybrook-York Mills                  41
# 66                1                           L'Amoreaux                 117
# 3                 4                                Annex                  95
# 95                1                    Parkwoods-Donalda                  45
# 9                 4                 Bedford Park-Nortown                  39
# 32                4  Dovercourt-Wallace Emerson-Junction                  93
# 70                3                   Leaside-Bennington                  56
# 33                1                 Downsview-Roding-CFB                  26
#
#      Children_Weight  Youth_Weight  Household_Income_Weight  \
# 129         2.081575      2.854792                 1.628790
# 132         3.384318      3.150967                 1.790700
# 105         2.798875      2.756067                 2.075729
# 58          2.046414      1.931304                 2.432910
# 104         0.922996      0.898807                 4.022853
# 73          2.781294      2.723159                 1.517900
# 69          1.000352      0.861785                 3.463330
# 16          0.504571      0.586179                 3.962723
# 66          2.151899      2.357055                 1.507028
# 3           0.829817      1.542575                 2.256080
# 95          2.053446      1.925134                 1.774823
# 9           1.601617      1.320444                 2.050248
# 32          1.575246      1.614562                 1.692335
# 70          1.155063      0.894694                 2.395890
# 33          2.013010      1.785274                 1.602141
#
#      College_Educated_Weight  Complex_Score
# 129                 4.041634       2.447116
# 132                 1.983504       2.420037
# 105                 1.771406       2.295561
# 58                  2.610631       2.290834
# 104                 1.573710       2.288244
# 73                  1.431003       1.994251
# 69                  1.129877       1.983735
# 16                  0.676879       1.938615
# 66                  1.811993       1.867001
# 3                   2.391987       1.855308
# 95                  1.598586       1.825362
# 9                   1.480754       1.700662
# 32                  1.855198       1.685935
# 70                  1.221524       1.612612
# 33                  0.877193       1.575952

# %%
df_top_16.set_index("Neighbourhood_Code", inplace=True)

# %% [markdown]
# **Week 2 - End of Census Dataset Analyzing**

# %% [markdown]
# ###12. Prepare the GEO data of the 140 neighbourhoods.

# %%
#Let us join the GEO table with these Census info table
df_geo_toronto = pd.read_csv(r'Neighbourhoods.csv', encoding = "ISO-8859-1", thousands=',')

df_geo_toronto.head()
# Out:
#     _id   AREA_ID  AREA_ATTR_ID  PARENT_AREA_ID  AREA_SHORT_CODE  \
# 0  2241  25886861      25926662           49885               94
# 1  2242  25886820      25926663           49885              100
# 2  2243  25886834      25926664           49885               97
# 3  2244  25886593      25926665           49885               27
# 4  2245  25886688      25926666           49885               31
#
#    AREA_LONG_CODE                     AREA_NAME                     AREA_DESC  \
# 0              94                 Wychwood (94)                 Wychwood (94)
# 1             100          Yonge-Eglinton (100)          Yonge-Eglinton (100)
# 2              97           Yonge-St.Clair (97)           Yonge-St.Clair (97)
# 3              27  York University Heights (27)  York University Heights (27)
# 4              31       Yorkdale-Glen Park (31)       Yorkdale-Glen Park (31)
#
#     X   Y  LONGITUDE   LATITUDE  OBJECTID   Shape__Area  Shape__Length  \
# 0 NaN NaN -79.425515  43.676919  16491505  3.217960e+06    7515.779658
# 1 NaN NaN -79.403590  43.704689  16491521  3.160334e+06    7872.021074
# 2 NaN NaN -79.397871  43.687859  16491537  2.222464e+06    8130.411276
# 3 NaN NaN -79.488883  43.765736  16491553  2.541821e+07   25632.335242
# 4 NaN NaN -79.457108  43.714672  16491569  1.156669e+07   13953.408098
#
#                                             geometry
# 0  {u'type': u'Polygon', u'coordinates': (((-79.4...
# 1  {u'type': u'Polygon', u'coordinates': (((-79.4...
# 2  {u'type': u'Polygon', u'coordinates': (((-79.3...
# 3  {u'type': u'Polygon', u'coordinates': (((-79.5...
# 4  {u'type': u'Polygon', u'coordinates': (((-79.4...

# %%
df_geo_neighbourhoods = df_geo_toronto[["AREA_SHORT_CODE","AREA_NAME", "LATITUDE", "LONGITUDE"]]

df_geo_neighbourhoods.set_index("AREA_SHORT_CODE")
df_geo_neighbourhoods.sort_values(["AREA_SHORT_CODE"], ascending=True).head()
# Out:
#      AREA_SHORT_CODE                              AREA_NAME   LATITUDE  \
# 63                 1             West Humber-Clairville (1)  43.716180
# 20                 2  Mount Olive-Silverstone-Jamestown (2)  43.746868
# 56                 3       Thistletown-Beaumond Heights (3)  43.737988
# 40                 4                    Rexdale-Kipling (4)  43.723725
# 112                5                   Elms-Old Rexdale (5)  43.721519
#
#      LONGITUDE
# 63  -79.596356
# 20  -79.587259
# 56  -79.563491
# 40  -79.566228
# 112 -79.548983

# %% [markdown]
# **Work of Week 2 start here**
#
# - Make dataset visualization thru **Folium map**
#
# - Analyzing Venues of Neighbourhoods thru **FourSquare API**
#
# - Make **Conculusions** after the data analyzing process had been done

# %% [markdown]
# ###13. Observing data thru maps
#
# **(1) First let us merge the Census dataset with the Neighbourhood GEO dataset**

# %%
df_census_neighbourhood_join = df_weights_info.set_index('Neighbourhood_Code').join(df_geo_neighbourhoods.set_index("AREA_SHORT_CODE"))
df_census_neighbourhood_join.shape
# Out:
# (140, 10)

# %%
df_census_neighbourhood_join.drop(columns=['AREA_NAME'], inplace=True)
df_census_neighbourhood_join.head()
# Out:
#                     Cluster Labels                 Neighbourhood  \
# Neighbourhood_Code
# 129                              4               Agincourt North
# 128                              4  Agincourt South-Malvern West
# 20                               0                     Alderwood
# 95                               4                         Annex
# 42                               4             Banbury-Don Mills
#
#                     Children_Weight  Youth_Weight  Household_Income_Weight  \
# Neighbourhood_Code
# 129                        1.350211      1.524064                 1.215673
# 128                        1.081224      1.382147                 0.792511
# 20                         0.618847      0.508021                 0.479970
# 95                         0.829817      1.542575                 2.256080
# 42                         1.267581      1.122995                 1.404838
#
#                     College_Educated_Weight  Complex_Score   LATITUDE  \
# Neighbourhood_Code
# 129                                1.146897       1.290504  43.805441
# 128                                1.102383       1.030155  43.788658
# 20                                 0.434669       0.504295  43.604937
# 95                                 2.391987       1.855308  43.671585
# 42                                 1.702016       1.380454  43.737657
#
#                     LONGITUDE
# Neighbourhood_Code
# 129                -79.266712
# 128                -79.265612
# 20                 -79.541611
# 95                 -79.404001
# 42                 -79.349718

# %% [markdown]
# **(2) Observing the Classified 140 neighbourhoods in the map**

# %%
#Create Clustering map
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_census_neighbourhood_join['LATITUDE'], df_census_neighbourhood_join['LONGITUDE'], df_census_neighbourhood_join['Neighbourhood'], df_census_neighbourhood_join['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <img src="map1.png" alt="K-Means_Clustering_Classified_Neighbourhoods" title="Classified Neighbourhoods" />

# %% [markdown]
# **(3) Let us observing the top 15 business oportunity neighbourhoods thru map**
#
# **Merge the top business opportunity dataframe with the neighbourhood GEO dataframe**<br>
# **Observing these classified neighbourhoods thru the map**

# %% [markdown]
# **Let us create a Barchar to observe the top 15 neighbourhoods more closely.**

# %%
df_top15_oportunities = df_top_16[["Neighbourhood", "Children_Weight", "Youth_Weight", "Household_Income_Weight", "College_Educated_Weight", "Complex_Score"]]
df_top15_oportunities.set_index("Neighbourhood", inplace=True)
df_top15_oportunities.plot(kind='bar', figsize=(20, 8))

plt.title('Top 15 Business Oportunies Distribution Chart')

plt.xlabel('Neighbourhoods')
plt.ylabel('Weights Distribution')
plt.show()

# %% [markdown]
# **(4) Visualization data distribution thru map**

# %%
df_top15_oportunities_geo = df_top_16.join(df_geo_neighbourhoods.set_index("AREA_SHORT_CODE"))
df_top15_oportunities_geo.drop(columns=["AREA_NAME"], inplace=True)
df_top15_oportunities_geo.head()
# Out:
#                     Cluster Labels               Neighbourhood  \
# Neighbourhood_Code
# 51                               2             Willowdale East
# 137                              1                      Woburn
# 131                              1                       Rouge
# 14                               1  Islington-City Centre West
# 98                               3         Rosedale-Moore Park
#
#                     Children_Weight  Youth_Weight  Household_Income_Weight  \
# Neighbourhood_Code
# 51                         2.081575      2.854792                 1.628790
# 137                        3.384318      3.150967                 1.790700
# 131                        2.798875      2.756067                 2.075729
# 14                         2.046414      1.931304                 2.432910
# 98                         0.922996      0.898807                 4.022853
#
#                     College_Educated_Weight  Complex_Score   LATITUDE  \
# Neighbourhood_Code
# 51                                 4.041634       2.447116  43.770602
# 137                                1.983504       2.420037  43.766740
# 131                                1.771406       2.295561  43.821201
# 14                                 2.610631       2.290834  43.633463
# 98                                 1.573710       2.288244  43.682820
#
#                     LONGITUDE
# Neighbourhood_Code
# 51                 -79.401484
# 137                -79.228586
# 131                -79.186343
# 14                 -79.543317
# 98                 -79.379669

# %% [markdown]
# **Here is the 15 most important locations ofr us in the map visualization**

# %%
# create map for top 15 business opportunities neighbourhoods
map_clusters_top15 = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_top15_oportunities_geo['LATITUDE'], df_top15_oportunities_geo['LONGITUDE'], df_top15_oportunities_geo['Neighbourhood'], df_top15_oportunities_geo['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters_top15)
       
map_clusters_top15
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <img src="map2.png" alt="top_15_business_locations" title="Neighbourhoods_for_Business" />

# %% [markdown]
# ###14. Utilizing the Foursquare API to explore the neighborhoods and segment them
# Define Foursquare Credentials and Version
# Now, let's get the top 100 venues that are in top 15 neighbourhoods within a radius of 1000 meters.
#
# First, let's create the GET request URL.
#
# Send Request thru the API call.
#
# Observing the result of the responsed JSON data.

# %%
# @hidden_cell
CLIENT_ID = 'URQCL0KJ4KGOL31CQW105ID4PCBVI0DCNXA3P12YF1GAVMKV' # your Foursquare ID
CLIENT_SECRET = 'JI4SDXR4RFB1JTHILGKJV2B1NXAIXXCPVWB22NRVU3NRXBMH' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 200
RADIUS = 2000

# %%
def getNearbyVenues(names, latitudes, longitudes, labels, radius):
    
    venues_list=[]
    for name, lat, lng, lb in zip(names, latitudes, longitudes, labels):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lb,
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 'Cluster Labels',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
top15_neighbourhoods_venues = getNearbyVenues(names=df_top15_oportunities_geo['Neighbourhood'],
                                              latitudes=df_top15_oportunities_geo['LATITUDE'],
                                              longitudes=df_top15_oportunities_geo['LONGITUDE'],
                                              labels=df_top15_oportunities_geo['Cluster Labels'],
                                              radius=RADIUS
                                             )

top15_neighbourhoods_venues.head()
# Out:
#       Neighborhood  Cluster Labels               Venue  Venue Latitude  \
# 0  Willowdale East               2        Maryam Hotel       43.766961
# 1  Willowdale East               2             The Keg       43.766579
# 2  Willowdale East               2       Konjiki Ramen       43.766998
# 3  Willowdale East               2  The Captain's Boil       43.773255
# 4  Willowdale East               2       Kinka Izakaya       43.760161
#
#    Venue Longitude       Venue Category
# 0       -79.401199                Hotel
# 1       -79.412131           Steakhouse
# 2       -79.412222     Ramen Restaurant
# 3       -79.413805   Seafood Restaurant
# 4       -79.409827  Japanese Restaurant

# %% [markdown]
# **Sort the neighbourhoods' Venues number from higher to lower.**<br>
# This information tells what are the most popular neighbourhoos for people running business. It is a very important factor for us to choose the best venue location.

# %%
top15_neighbourhoods_venues.groupby('Neighborhood').count().sort_values(by='Venue', ascending=False)
# Out:
#                                      Cluster Labels  Venue  Venue Latitude  \
# Neighborhood
# Annex                                           100    100             100
# Bedford Park-Nortown                            100    100             100
# Dovercourt-Wallace Emerson-Junction             100    100             100
# Lawrence Park South                             100    100             100
# Leaside-Bennington                              100    100             100
# Parkwoods-Donalda                               100    100             100
# Rosedale-Moore Park                             100    100             100
# Woburn                                           78     78              78
# L'Amoreaux                                       63     63              63
# Bridle Path-Sunnybrook-York Mills                62     62              62
# Downsview-Roding-CFB                             62     62              62
# Malvern                                          48     48              48
# Islington-City Centre West                       46     46              46
# Willowdale East                                  38     38              38
# Rouge                                            31     31              31
#
#                                      Venue Longitude  Venue Category
# Neighborhood
# Annex                                            100             100
# Bedford Park-Nortown                             100             100
# Dovercourt-Wallace Emerson-Junction              100             100
# Lawrence Park South                              100             100
# Leaside-Bennington                               100             100
# Parkwoods-Donalda                                100             100
# Rosedale-Moore Park                              100             100
# Woburn                                            78              78
# L'Amoreaux                                        63              63
# Bridle Path-Sunnybrook-York Mills                 62              62
# Downsview-Roding-CFB                              62              62
# Malvern                                           48              48
# Islington-City Centre West                        46              46
# Willowdale East                                   38              38
# Rouge                                             31              31

# %% [markdown]
# ###15. Observing Education activity related venues in this to 15 neighbourhoods.
#
# It gives us the firm idea which neighbour hood is a good place to operate the Education Activity related venues.
#
# **Look into the venues category**<br>
#
# Research on existing similar venues like **Learning Center**.

# %%
top15_neighbourhoods_venues[top15_neighbourhoods_venues["Venue Category"].str.contains('Museum|School|Music|Bookstore|Learning|Dance|Sports')]
# Out:
#                              Neighborhood  Cluster Labels  \
# 46                                 Woburn               1
# 52                                 Woburn               1
# 55                                 Woburn               1
# 194                   Rosedale-Moore Park               3
# 242                   Rosedale-Moore Park               3
# 244                   Rosedale-Moore Park               3
# 361                   Lawrence Park South               3
# 367                   Lawrence Park South               3
# 548                            L'Amoreaux               1
# 564                            L'Amoreaux               1
# 574                                 Annex               4
# 577                                 Annex               4
# 584                                 Annex               4
# 615                                 Annex               4
# 628                                 Annex               4
# 638                                 Annex               4
# 800                  Bedford Park-Nortown               4
# 884   Dovercourt-Wallace Emerson-Junction               4
# 972                    Leaside-Bennington               3
# 1076                 Downsview-Roding-CFB               1
# 1116                 Downsview-Roding-CFB               1
# 1118                 Downsview-Roding-CFB               1
# 1120                 Downsview-Roding-CFB               1
# 1121                 Downsview-Roding-CFB               1
# 1124                 Downsview-Roding-CFB               1
#
#                                          Venue  Venue Latitude  \
# 46                              Long & McQuade       43.775903
# 52                              The Comic Room       43.754258
# 55                Centennial Recreation Centre       43.774593
# 194                   Toronto Lawn Tennis Club       43.680667
# 242                          DanceLifeX Centre       43.666956
# 244                                     Indigo       43.669065
# 361                                     Indigo       43.707750
# 367                                  BMV Books       43.707450
# 548                   L'Amoreaux Sports Centre       43.803002
# 564     L'Amoreaux Community Recreation Centre       43.812106
# 574                       Royal Ontario Museum       43.668367
# 577                Royal Conservatory of Music       43.668228
# 584                                  BMV Books       43.665860
# 615                               Nella Cucina       43.667122
# 628                          Casa Loma Stables       43.679395
# 638                                     Indigo       43.669065
# 800   Toronto Cricket Skating and Curling Club       43.739660
# 884         Long & McQuade Musical Instruments       43.661637
# 972                              Local Leaside       43.710012
# 1076               The Hangar @ Downsview Park       43.746713
# 1116                                  Edgefest       43.745440
# 1118                      Color Me Rad Toronto       43.746112
# 1120                               Penalty Box       43.745785
# 1121           Downsview Park Ultimate Frisbee       43.743883
# 1124                   National Squash Academy       43.745794
#
#       Venue Longitude      Venue Category
# 46         -79.230965         Music Store
# 52         -79.244319           Bookstore
# 55         -79.236500  Athletics & Sports
# 194        -79.388559  Athletics & Sports
# 242        -79.385297        Dance Studio
# 244        -79.389057           Bookstore
# 361        -79.398565           Bookstore
# 367        -79.398457           Bookstore
# 548        -79.304475  Athletics & Sports
# 564        -79.305097  Athletics & Sports
# 574        -79.394813              Museum
# 577        -79.396311        Music School
# 584        -79.406824           Bookstore
# 615        -79.412022              School
# 628        -79.410905              Museum
# 638        -79.389057           Bookstore
# 800        -79.418732         Sports Club
# 884        -79.427099         Music Store
# 972        -79.363514          Sports Bar
# 1076       -79.474082  Athletics & Sports
# 1116       -79.480300         Music Venue
# 1118       -79.481036  Athletics & Sports
# 1120       -79.476203          Sports Bar
# 1121       -79.473292  Athletics & Sports
# 1124       -79.473352  Athletics & Sports

# %% [markdown]
# ### 16. Results
#
# **The final dataframe contains the most venues blooming neighbourhoods**

# %%
df_top15_oportunities_geo[df_top15_oportunities_geo['Neighbourhood'].isin(['Annex', 'Bedford Park-Nortown', 'Dovercourt-Wallace Emerson-Junction', 'Rosedale-Moore Park', 'Lawrence Park South', 'Leaside-Bennington', 'Downsview-Roding-CFB', "L'Amoreaux", 'Woburn'])]
# Out:
#                     Cluster Labels                        Neighbourhood  \
# Neighbourhood_Code
# 137                              1                               Woburn
# 98                               3                  Rosedale-Moore Park
# 103                              3                  Lawrence Park South
# 117                              1                           L'Amoreaux
# 95                               4                                Annex
# 39                               4                 Bedford Park-Nortown
# 93                               4  Dovercourt-Wallace Emerson-Junction
# 56                               3                   Leaside-Bennington
# 26                               1                 Downsview-Roding-CFB
#
#                     Children_Weight  Youth_Weight  Household_Income_Weight  \
# Neighbourhood_Code
# 137                        3.384318      3.150967                 1.790700
# 98                         0.922996      0.898807                 4.022853
# 103                        1.000352      0.861785                 3.463330
# 117                        2.151899      2.357055                 1.507028
# 95                         0.829817      1.542575                 2.256080
# 39                         1.601617      1.320444                 2.050248
# 93                         1.575246      1.614562                 1.692335
# 56                         1.155063      0.894694                 2.395890
# 26                         2.013010      1.785274                 1.602141
#
#                     College_Educated_Weight  Complex_Score   LATITUDE  \
# Neighbourhood_Code
# 137                                1.983504       2.420037  43.766740
# 98                                 1.573710       2.288244  43.682820
# 103                                1.129877       1.983735  43.717212
# 117                                1.811993       1.867001  43.795716
# 95                                 2.391987       1.855308  43.671585
# 39                                 1.480754       1.700662  43.731486
# 93                                 1.855198       1.685935  43.665677
# 56                                 1.221524       1.612612  43.703797
# 26                                 0.877193       1.575952  43.733292
#
#                     LONGITUDE
# Neighbourhood_Code
# 137                -79.228586
# 98                 -79.379669
# 103                -79.406039
# 117                -79.314084
# 95                 -79.404001
# 39                 -79.420227
# 93                 -79.438541
# 56                 -79.366072
# 26                 -79.490497

# %% [markdown]
# ###17. Discussion
# From the results discovered and presented, the following observations and recommendations can be made: Based on the criteria given by the investor team and the cluster data, the main neighborhood recommendation would be for the neighborhood of **Annex**. With a total score of 1.86 and being in the cluster 4, this area is a prime location for a **Learning Center**. A secondary recommendation is made for the neighborhood of **Lawrence Park South**. This neighborhood a ranking in the top fifteen total score assessment, as well as having less competition.

# %% [markdown]
# ###18. Conclusions
# From above research of corelated Venues, we do not find any competitors who have same businesses in our search radar. Following are top neighbourhoods which are ideal locations to operate the **Learning Center** venues.
#
# -  Annex
# - Bedford Park-Nortown
# - Dovercourt-Wallace Emerson-Junction
# - Rosedale-Moore Park
# - Lawrence Park South
# - Leaside-Bennington
# - Downsview-Roding-CFB
# - L'Amoreaux
# - Woburn

# %% [markdown]
# ## 19. Machine Learning Part - RandomForest Classifier Model
#
# After finished the task to find the best location for operating the **Learning Center** business in City of Toronto. We realized we could build a machine learning model for this investor team for finding other opportunities in the rest of the cities in Canada.
#
# **Here is how we start.**<br>
# 1. Create the Census DataSet for 140 neighbourhoods with selected data items, such population od Children, Youth, College Graduated people, after tax Household Income.
# 2. Create the venues DataSet for 140 neighbourhoods, summarize all categories for each neighbourhood
# 3. Merge these two above datsets
# 4. Calculate all items weights
# 5. Add a predictable column with clustering labels 0, 1, 2, 3, 4, 5, 6. The higher the value of the label means better neighbourhood for running **Learning Center** business.

# %% [markdown]
# **1. The extracted Census data**

# %%
df_family_info_t.head()
# Out:
#                   Neighbourhood  Neighbourhood_Code  Children  Youth  \
# 0               Agincourt North                 129      3840   3705
# 1  Agincourt South-Malvern West                 128      3075   3360
# 2                     Alderwood                  20      1760   1235
# 3                         Annex                  95      2360   3750
# 4             Banbury-Don Mills                  42      3605   2730
#
#    Avg_Household_Income  College_Educated  Children_Weight  Youth_Weight  \
# 0                427037              4380         1.350211      1.524064
# 1                278390              4210         1.081224      1.382147
# 2                168602              1660         0.618847      0.508021
# 3                792507              9135         0.829817      1.542575
# 4                493486              6500         1.267581      1.122995
#
#    Household_Income_Weight  College_Educated_Weight
# 0                 1.215673                 1.146897
# 1                 0.792511                 1.102383
# 2                 0.479970                 0.434669
# 3                 2.256080                 2.391987
# 4                 1.404838                 1.702016

# %% [markdown]
# **2. Create a subset of the Census data for next step**

# %%
df_census_status = df_family_info_t[["Neighbourhood", "Neighbourhood_Code", "Children", "Youth", "Avg_Household_Income", "College_Educated"]]
df_census_status.head()
# Out:
#                   Neighbourhood  Neighbourhood_Code  Children  Youth  \
# 0               Agincourt North                 129      3840   3705
# 1  Agincourt South-Malvern West                 128      3075   3360
# 2                     Alderwood                  20      1760   1235
# 3                         Annex                  95      2360   3750
# 4             Banbury-Don Mills                  42      3605   2730
#
#    Avg_Household_Income  College_Educated
# 0                427037              4380
# 1                278390              4210
# 2                168602              1660
# 3                792507              9135
# 4                493486              6500

# %% [markdown]
# **3. The original GEO information for 140 neighbourhoods**

# %%
df_geo_neighbourhoods.head()
# Out:
#    AREA_SHORT_CODE                     AREA_NAME   LATITUDE  LONGITUDE
# 0               94                 Wychwood (94)  43.676919 -79.425515
# 1              100          Yonge-Eglinton (100)  43.704689 -79.403590
# 2               97           Yonge-St.Clair (97)  43.687859 -79.397871
# 3               27  York University Heights (27)  43.765736 -79.488883
# 4               31       Yorkdale-Glen Park (31)  43.714672 -79.457108

# %% [markdown]
# **4. Collect all existing venues for 140 neighbourhoods**<br>
#
# The reason we do this, is because we realize the existing Venues status is a significant factor for business activities, for instance the volume of customer flow, the real estate cost etc.

# %%
def getNeighbourhoodVenues(names, latitudes, longitudes, areacode, radius):
    
    venues_list=[]
    for name, lat, lng, neighbourcode in zip(names, latitudes, longitudes, areacode):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            neighbourcode,
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 'Neighbourhood_Code',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
df_neighbourhoods_venues = getNeighbourhoodVenues(names=df_geo_neighbourhoods['AREA_NAME'],
                                              latitudes=df_geo_neighbourhoods['LATITUDE'],
                                              longitudes=df_geo_neighbourhoods['LONGITUDE'],
                                              areacode=df_geo_neighbourhoods['AREA_SHORT_CODE'],
                                              radius=RADIUS
                                             )

df_neighbourhoods_venues.head()
# Out:
#     Neighborhood  Neighbourhood_Code                           Venue  \
# 0  Wychwood (94)                  94                  Wychwood Barns
# 1  Wychwood (94)                  94  Wychwood Barns Farmers' Market
# 2  Wychwood (94)                  94                Pukka Restaurant
# 3  Wychwood (94)                  94                  The Stockyards
# 4  Wychwood (94)                  94                      CocoaLatte
#
#    Venue Latitude  Venue Longitude     Venue Category
# 0       43.680028       -79.423810        Event Space
# 1       43.680010       -79.423849     Farmers Market
# 2       43.681055       -79.429187  Indian Restaurant
# 3       43.681570       -79.426210          BBQ Joint
# 4       43.681768       -79.425158               Café

# %% [markdown]
# **5. Summarize all venues group by neighbourhoods**

# %%
df_neighbourhood_venues_count = df_neighbourhoods_venues.groupby('Neighbourhood_Code').count().sort_values(by='Venue', ascending=False)
df_neighbourhood_venues_count.head()
# Out:
#                     Neighborhood  Venue  Venue Latitude  Venue Longitude  \
# Neighbourhood_Code
# 71                           100    100             100              100
# 75                           100    100             100              100
# 86                           100    100             100              100
# 85                           100    100             100              100
# 84                           100    100             100              100
#
#                     Venue Category
# Neighbourhood_Code
# 71                             100
# 75                             100
# 86                             100
# 85                             100
# 84                             100

# %%
df_neighbourhood_venues_count.drop(columns=['Neighborhood', 'Venue Latitude', 'Venue Longitude', 'Venue Category'], inplace=True)
df_neighbourhood_venues_count.head()
# Out:
#                     Venue
# Neighbourhood_Code
# 71                    100
# 75                    100
# 86                    100
# 85                    100
# 84                    100

# %% [markdown]
# **6. Merge the Census data with Venues data, indexed with Neighbourhood_Code. Manipulate data to be ready for Classification**

# %%
#Prepare for the Venues DataSet
df_census_geo_venue = df_census_status.set_index('Neighbourhood_Code').join(df_neighbourhood_venues_count)
df_census_geo_venue.head()
# Out:
#                                    Neighbourhood  Children  Youth  \
# Neighbourhood_Code
# 129                              Agincourt North      3840   3705
# 128                 Agincourt South-Malvern West      3075   3360
# 20                                     Alderwood      1760   1235
# 95                                         Annex      2360   3750
# 42                             Banbury-Don Mills      3605   2730
#
#                     Avg_Household_Income  College_Educated  Venue
# Neighbourhood_Code
# 129                               427037              4380     40
# 128                               278390              4210    100
# 20                                168602              1660    100
# 95                                792507              9135    100
# 42                                493486              6500    100

# %% [markdown]
# **Checking the statistic information of the dataset**

# %%
df_census_geo_venue.describe()
# Out:
#           Children        Youth  Avg_Household_Income  College_Educated  \
# count   140.000000   140.000000          1.400000e+02        140.000000
# mean   2843.964286  2430.928571          3.512761e+05       3819.000000
# std    1546.225445  1457.994778          2.309379e+05       3046.742287
# min     565.000000   675.000000          1.022590e+05        445.000000
# 25%    1695.000000  1428.750000          1.953375e+05       2053.750000
# 50%    2405.000000  2100.000000          2.915495e+05       3257.500000
# 75%    3567.500000  3022.500000          4.305408e+05       4385.000000
# max    9625.000000  7840.000000          1.413132e+06      27280.000000
#
#             Venue
# count  140.000000
# mean    78.985714
# std     25.475616
# min     14.000000
# 25%     54.000000
# 50%     98.500000
# 75%    100.000000
# max    100.000000

# %% [markdown]
# **Rename column Venue to Venue_Count**

# %%
df_census_geo_venue.rename(columns={"Venue":"Venue_Count"}, inplace=True)
df_census_geo_venue.head()
# Out:
#                                    Neighbourhood  Children  Youth  \
# Neighbourhood_Code
# 129                              Agincourt North      3840   3705
# 128                 Agincourt South-Malvern West      3075   3360
# 20                                     Alderwood      1760   1235
# 95                                         Annex      2360   3750
# 42                             Banbury-Don Mills      3605   2730
#
#                     Avg_Household_Income  College_Educated  Venue_Count
# Neighbourhood_Code
# 129                               427037              4380           40
# 128                               278390              4210          100
# 20                                168602              1660          100
# 95                                792507              9135          100
# 42                                493486              6500          100

# %% [markdown]
# **Normalize all data elements**

# %%
#df_census_geo_venue.mean(axis=0)

#Scale columns Population of Children, Youth, Household_Income after tax, and finished College Education population
#The weights scale will be used for K clustering

df_census_geo_venue["Children_Weight"] = df_census_geo_venue["Children"].divide(df_census_geo_venue["Children"].mean())
df_census_geo_venue["Youth_Weight"] = df_census_geo_venue["Youth"].divide(df_census_geo_venue["Youth"].mean())
df_census_geo_venue["Household_Income_Weight"] = df_census_geo_venue["Avg_Household_Income"].divide(df_census_geo_venue["Avg_Household_Income"].mean())
df_census_geo_venue["College_Educated_Weight"] = df_census_geo_venue["College_Educated"].divide(df_census_geo_venue["College_Educated"].mean())
df_census_geo_venue["Venue_Weight"] = df_census_geo_venue["Venue_Count"].divide(df_census_geo_venue["Venue_Count"].mean())
df_census_geo_venue.head()
# Out:
#                                    Neighbourhood  Children  Youth  \
# Neighbourhood_Code
# 129                              Agincourt North      3840   3705
# 128                 Agincourt South-Malvern West      3075   3360
# 20                                     Alderwood      1760   1235
# 95                                         Annex      2360   3750
# 42                             Banbury-Don Mills      3605   2730
#
#                     Avg_Household_Income  College_Educated  Venue_Count  \
# Neighbourhood_Code
# 129                               427037              4380           40
# 128                               278390              4210          100
# 20                                168602              1660          100
# 95                                792507              9135          100
# 42                                493486              6500          100
#
#                     Children_Weight  Youth_Weight  Household_Income_Weight  \
# Neighbourhood_Code
# 129                        1.350228      1.524109                 1.215673
# 128                        1.081237      1.382188                 0.792510
# 20                         0.618854      0.508036                 0.479970
# 95                         0.829828      1.542620                 2.256080
# 42                         1.267597      1.123028                 1.404838
#
#                     College_Educated_Weight  Venue_Weight
# Neighbourhood_Code
# 129                                1.146897      0.506421
# 128                                1.102383      1.266052
# 20                                 0.434669      1.266052
# 95                                 2.391987      1.266052
# 42                                 1.702016      1.266052

# %% [markdown]
# **Here is the Normalized dataset**

# %%
df_ML_model = df_census_geo_venue[['Children_Weight', 'Youth_Weight', 'Household_Income_Weight', 'College_Educated_Weight', 'Venue_Weight']]
df_ML_model.head()
# Out:
#                     Children_Weight  Youth_Weight  Household_Income_Weight  \
# Neighbourhood_Code
# 129                        1.350228      1.524109                 1.215673
# 128                        1.081237      1.382188                 0.792510
# 20                         0.618854      0.508036                 0.479970
# 95                         0.829828      1.542620                 2.256080
# 42                         1.267597      1.123028                 1.404838
#
#                     College_Educated_Weight  Venue_Weight
# Neighbourhood_Code
# 129                                1.146897      0.506421
# 128                                1.102383      1.266052
# 20                                 0.434669      1.266052
# 95                                 2.391987      1.266052
# 42                                 1.702016      1.266052

# %% [markdown]
# **7. Applying K-Means clustering classification**

# %%
#Apply K-Means Clustering Classification

#To have the better effectives of the clustering classification, the data is transformed with StandardScaler call.

df_ML_model_X = StandardScaler().fit_transform(df_ML_model)
df_ML_model_X

# %% [markdown]
# **Running classification**

# %%
#let us run K clustering
# set number of clusters
kclusters = 7

# run k-means clustering
kmeans_ML = KMeans(n_clusters=kclusters, random_state=4).fit(df_ML_model_X)

# check cluster labels generated for each row in the dataframe
kmeans_ML.labels_[0:10]
# Out:
# array([1, 6, 0, 6, 6, 3, 6, 6, 3, 6], dtype=int32)

# %% [markdown]
# **Review all labels**

# %%
kmeans_ML.labels_
# Out:
# array([1, 6, 0, 6, 6, 3, 6, 6, 3, 6, 3, 6, 3, 1, 0, 3, 2, 0, 3, 0, 0, 0,
#        3, 6, 6, 3, 3, 0, 0, 0, 6, 6, 6, 1, 0, 6, 3, 1, 3, 6, 3, 3, 1, 0,
#        2, 1, 0, 3, 0, 6, 6, 3, 0, 3, 3, 3, 0, 0, 5, 0, 0, 3, 0, 1, 2, 0,
#        5, 0, 3, 2, 2, 0, 3, 5, 0, 3, 6, 6, 3, 0, 3, 1, 0, 6, 3, 0, 6, 6,
#        0, 0, 0, 0, 3, 0, 0, 6, 3, 0, 0, 3, 0, 3, 0, 0, 2, 5, 0, 3, 3, 0,
#        6, 6, 6, 6, 6, 0, 6, 3, 1, 0, 0, 3, 4, 1, 1, 6, 3, 0, 6, 5, 0, 1,
#        5, 0, 3, 0, 0, 0, 1, 0], dtype=int32)

# %% [markdown]
# **Merge labels with existing dataset**

# %%
df_ML_model.insert(0, 'Cluster Labels', kmeans_ML.labels_)
#df_ML_model.sort_values(by="Cluster Labels", ascending=False)

# %% [markdown]
# **Review the classified dataset**

# %%
df_ML_model.sort_values(by="Cluster Labels", ascending=False).head()
# Out:
#                     Cluster Labels  Children_Weight  Youth_Weight  \
# Neighbourhood_Code
# 40                               6         0.930040      1.044868
# 116                              6         1.107609      1.104516
# 104                              6         0.836860      1.036641
# 62                               6         1.313308      0.909118
# 63                               6         1.344954      0.853583
#
#                     Household_Income_Weight  College_Educated_Weight  \
# Neighbourhood_Code
# 40                                 1.848378                 1.099764
# 116                                1.033503                 1.131186
# 104                                1.261250                 2.428646
# 62                                 0.865445                 1.159990
# 63                                 1.876564                 1.493847
#
#                     Venue_Weight
# Neighbourhood_Code
# 40                      1.164768
# 116                     1.266052
# 104                     1.266052
# 62                      1.266052
# 63                      1.266052

# %% [markdown]
# **8. Building the machine learning model**<br>
#
# 1. Spliting the dataset into two parts of train set and test set.<br>
# 2. Training the RandomForestClassifier model
# 3. Save the model to file and deliver it to investor team

# %%
X = df_ML_model[['Children_Weight',	'Youth_Weight',	'Household_Income_Weight',	'College_Educated_Weight',	'Venue_Weight']].values
y = df_ML_model["Cluster Labels"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_trainset, y_trainset)

y_pred=clf.predict(X_testset)

# %%
print(y_pred)
# Out:
# [6 6 6 3 3 0 1 3 6 3 6 0 1 6 6 3 3 3 6 6 3 0 5 5 3 0 3 0 0 6 3 3 6 6 3 0 0
#  1 6 3 0 0]

# %% [markdown]
# **Save the trained model for production purpose (delivery)**

# %%
import pickle

filename_model = '/tmp/finalized_model.sav'
pickle.dump(clf, open(filename_model, 'wb'))

# %% [markdown]
# **Load this model to run prediction test**

# %%
loaded_model = pickle.load(open(filename_model, 'rb'))

# %% [markdown]
# **Test with a good location case**<br>
# The label is 6, means a highly recommended location for business.

# %%
print(loaded_model.predict([[1.0, 1.2, 3, 2, 1.5]]))
# Out:
# [6]

# %% [markdown]
# **Try a worst case**<br>
# The label is 2, means a location not good for business.

# %%
print(clf.predict([[0.1, 0.2, 3, 2, 0.5]]))
# Out:
# [2]
